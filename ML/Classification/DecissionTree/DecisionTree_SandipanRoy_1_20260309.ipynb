# %% [markdown]
# <div style="display:flex;align-items:center;justify-content:center;flex-direction:column;padding:18px 0;">
# <h1 style="font-family: 'Segoe UI', Roboto, Arial; font-size:48px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">
# DECISION TREE ASSIGNMENT
# </h1>
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">A concise workbook covering how to build random forest models, evaluate their performance, and interpret the derived meaningful insights.</p>
# </div>
#
# ---
#
# <div style="display:flex;gap:12px;flex-wrap:wrap;align-items:center;">
# <span style="background:#eef2ff;color:#3730a3;padding:6px 10px;border-radius:8px;font-weight:600;">📘 Basics</span>
# <span style="background:#ecfdf5;color:#065f46;padding:6px 10px;border-radius:8px;font-weight:600;">⚙️ Examples</span>
# <span style="background:#fff7ed;color:#92400e;padding:6px 10px;border-radius:8px;font-weight:600;">🔁 Exercises</span>
# </div>
#
#
# <details><summary><strong>Notebook info</strong></summary>
#
# - **Author:** Sandipan Roy
# - **Assignment Date:** 2026-03-16
# - **Assignment Given By:** Karkavel Raja
# - **Sections:** Importing Libraries · Data Loading · Data Preprocessing & Transformation Operations · Exploratory Data Analysis (EDA) · Fine-tuning and Optimization · Model Building · Model Evaluation · Model Optimization and Insights
#
# </details>
#
# ---

# %% [markdown]
# <div style="display:flex;align-items:center;justify-content:center;flex-direction:column;padding:18px 0;">
# <h2 style="font-family: 'Segoe UI', Roboto, Arial; font-size:38px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">Problem Statement:</h2>
#
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">This assignment aims to utilize Decision Tree algorithms to analyze given datasets, extracting meaningful insights and predicting outcomes based on the decision rules learned from the data. By exploring the datasets, students will learn how to build classification models, evaluate their performance, interpret and derive meaningful insights.</p>
# </div>
#
# ---

# %% [markdown]
# <div style="display:flex;align-items:center;justify-content:center;flex-direction:column;padding:18px 0;">
# <h2 style="font-family: 'Segoe UI', Roboto, Arial; font-size:38px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">Dataset for the Assignment:</h2>
#
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
#
#
# -   [Obesity Classification Dataset | Kaggle](https://www.kaggle.com/datasets/sujithmandala/obesity-classification-dataset)
# -   [Email Spam Classification Dataset | Kaggle](https://www.kaggle.com/datasets/balaka18/email-spam-classification-dataset-csv)
# -   [Heart Attack Analysis & Prediction Dataset | Kaggle](https://www.kaggle.com/datasets/algozee/heart-decices)
#
#
# </p>
# </div>
#
# ---

# %% [markdown]
# <div style="display:flex;align-items:center;justify-content:center;flex-direction:column;padding:18px 0;">
# <h2 style="font-family: 'Segoe UI', Roboto, Arial; font-size:38px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">Business Objective:</h2>
#
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
#
# - [Heart Attack Analysis & Prediction Dataset | Kaggle](https://www.kaggle.com/datasets/algozee/heart-decices) :- This project is based on the application of Machine Learning techniques to predict the likelihood of heart disease using structured clinical data.
#
# Heart disease is one of the leading causes of death worldwide and remains a major public health concern. Cardiovascular diseases often develop due to a combination of factors such as high blood pressure, high cholesterol levels, unhealthy lifestyle habits, genetic predisposition, and other medical conditions. Early detection and timely medical intervention play a crucial role in reducing mortality rates and improving patient outcomes. Traditional diagnostic procedures rely heavily on clinical examinations, laboratory tests, and the expertise of medical professionals, which can sometimes be time-consuming and costly. With the advancement of technology, Machine Learning and data analytics have emerged as powerful tools in the healthcare sector. These technologies enable the analysis of large amounts of patient data to identify patterns and predict potential health risks.
#
# The main objectives of this project are:
#
# - To analyze and preprocess the heart disease dataset for effective model training.
# - To identify significant clinical features influencing heart disease prediction.
# - To develop and train Machine Learning classification models using the training dataset.
# - To evaluate the performance of the models using appropriate evaluation metrics.
# - To build a reliable predictive system that can assist in early detection of heart disease.
#
# </p>
# </div>
#
# ---

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">1. Setup and Data Preparation:</h3>

# %% [markdown]
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Install the required libraries if not present.</u></li>
# </ul>
# </p>
#
# ---

# %%
# !pip install scikit-learn
# !pip install statsmodels
# !pip install -U imbalanced-learn
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Import all the required libraries and orchastrate control over the behaviour and display settings of pandas.</u></li>
# </ul>
# </p>
#
# ---

# %%
# Importing warning to disable runtime warnings
import warnings
# Warnings will appear only once
warnings.filterwarnings("ignore")

#=================================================================================

# Importing Numpy Library and aliasing it's name as np
import numpy as np
# Importing Pandas Library and aliasing it's name as pd
import pandas as pd
# Importing the Pyplot Interface from within the Matplotlib Library and aliasing it as plt
import matplotlib.pyplot as plt
# The above line of code can also be written as-
#    from matplotlib import pyplot as plt

# Importing Seaborn Library and aliasing it's name as sns
import seaborn as sns

# Importing the Plotly Express Interface from within the Plotly Library and aliasing it as px
import plotly.express as px

import pickle

from imblearn.combine import SMOTEENN
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import roc_curve, roc_auc_score, RocCurveDisplay
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, KFold

#=================================================================================

# Unfolding hidden features if the cardinality is high
pd.set_option('display.max_columns', None)
# Unfolding the max feature width for better clearity
pd.set_option('display.max_colwidth', None)
# Unfolding hidden data points if the cardinality is high
pd.set_option('display.max_rows', None)
# Removing restriction over chained assignments operations
pd.set_option('mode.chained_assignment', None)
# To suppress scientific notation over exponential values
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %matplotlib inline

# %% [markdown]
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Acquire data from datasource and bring it in-memory.</u></li>
# </ul>
# </p>
#
# ---

# %%
def acquire_data(url, sourceType="csv", verbose=False):
    """
    This function acquires data from the given URL and returns a DataFrame.

    Parameters:
    url (str): The URL from which to acquire the data.
    sourceType (str): The type of the data source (default is "csv").
    verbose (bool): If True, prints the shape of the DataFrame and its columns.

    Returns:
    pd.DataFrame: The acquired data as a DataFrame.
    """

    if sourceType.lower() != "csv":
        raise ValueError("Currently, only 'csv' source type is supported.")

    # Reading the CSV file from the provided URL
    df = pd.read_csv(url)

    # If verbose is True, print the shape of the DataFrame and its columns
    if verbose:
        print(f"DataFrame Shape: {df.shape}, i.e., {df.shape[0]} rows and {df.shape[1]} columns.")
        print(f"DataFrame Columns: {df.columns.tolist()}")

    return df

# %%
url_train = "https://raw.githubusercontent.com/Sandipan-Roy/sr/refs/heads/Dev/ML/DecissionTree/data/raw/heart_disease_train.csv"
url_test = "https://raw.githubusercontent.com/Sandipan-Roy/sr/refs/heads/Dev/ML/DecissionTree/data/raw/heart_disease_test.csv"

data = acquire_data(url_train, verbose=True)

test_data = acquire_data(url_test, verbose=True)
# Out:
# DataFrame Shape: (630000, 15), i.e., 630000 rows and 15 columns.
# DataFrame Columns: ['id', 'Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease']
# DataFrame Shape: (270000, 14), i.e., 270000 rows and 14 columns.
# DataFrame Columns: ['id', 'Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120', 'EKG results', 'Max HR', 'Exercise angina', 'ST depression', 'Slope of ST', 'Number of vessels fluro', 'Thallium']

# %% [markdown]
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Analyze the aquired data and perform pre-profiling.</u></li>
# </ul>
# </p>
#
# ---

# %%
def analyze_data(df):
    """
    This function performs basic analysis on the given DataFrame and prints the results.

    Parameters:
    df (pd.DataFrame): The DataFrame to analyze.

    Returns:
    __dict__: A dictionary containing the results of the numerical columns and categorical columns list.
    """

    # Displaying the first 5 rows of the DataFrame
    print("First 5 rows of the DataFrame:")
    print(df.head())

    # Displaying the last 5 rows of the DataFrame
    print("\nLast 5 rows of the DataFrame:")
    print(df.tail())

    # Displaying the shape of the DataFrame
    print(f"\nShape of the DataFrame: {df.shape}")

    # Displaying the data types of each column
    print("\nData types of each column:")
    print(df.dtypes)

    #Displaying information about the DataFrame
    print("\nInformation about the DataFrame:")
    print(df.info())

    # Displaying the memory usage of the DataFrame
    print(f"\nMemory usage of the DataFrame: {(df.memory_usage(deep=True)).sum() / 1024:.2f} KB")  # Converting bytes to kilobytes
    print(((df.memory_usage(deep=True)) / 1024).round(2))  # Converting bytes to kilobytes

    # Listing numerical columns
    numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    # Listing categorical columns
    categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
    print("\nWe have {} numerical features: {}".format(len(numerical_cols), numerical_cols))
    print("We have {} categorical features: {}".format(len(categorical_cols), categorical_cols))

    print("\nNumber of duplicated rows: {} ({}% of total rows)".format(
                    df.duplicated().sum(),
                    round(df.duplicated().sum() / df.shape[0] * 100, 2)
                    ))

    if len(numerical_cols) > 0:
      # Displaying summary statistics for numerical columns
      print("\nSummary statistics for numerical columns:")
      print(df.describe())

    if len(categorical_cols) > 0:
      # Displaying summary statistics for categorical columns
      print("\nSummary statistics for categorical columns:")
      print(df.describe(include=['object']))


    # Returning the list of numerical and categorical columns
    return {
        "numerical_columns": numerical_cols if len(numerical_cols) > 0 else None,
        "categorical_columns": categorical_cols if len(categorical_cols) > 0 else None
    }

# %%
dictColumns = analyze_data(data)
numerical_columns = dictColumns["numerical_columns"]
categorical_columns = dictColumns["categorical_columns"]
# Out:
# First 5 rows of the DataFrame:
#    id  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0   0   58    1                4  152          239             0            0
# 1   1   52    1                1  125          325             0            2
# 2   2   56    0                2  160          188             0            2
# 3   3   44    0                3  134          229             0            2
# 4   4   58    1                4  140          234             0            2
#
#    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0     158                1        3.60000            2
# 1     171                0        0.00000            1
# 2     151                0        0.00000            1
# 3     150                0        1.00000            2
# 4     125                1        3.80000            2
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        2         7      Presence
# ...

# %% [markdown]
# ---
# <a name = Section4></a>
# ### Data Acquisition Observations
# ---
# The dataset consists of the "target" field refers to the presence of heart disease in the patient. It is integer valued 0 = no disease and 1 = disease.
#
# | Records | Features | Dataset Size |
# | :-- | :-- | :-- |
# | 630000 | 15 | 72.1+ MB |
#
#
# | ID | Feature Name | Description of the feature | Data Type |
# | :-- | :--| :--| :--|
# |01| **id**   |   | int64 |
# |02| **Age**   | age in years  | int64 |
# |03| **Sex**   | (1 = male; 0 = female)   | int64 |
# |04| **Chest pain type**   | chest pain type(4 values)   | int64 |
# |05| **BP**   | resting blood pressure (in mm Hg on admission to the hospital)  | int64 |
# |06| **Cholesterol**   | serum cholestoral in mg/dl | int64 |
# |07| **FBS over 120**   | (fasting blood sugar > 120 mg/dl) (1 = true; 0 = false) | int64 |
# |08| **EKG results**   | resting electrocardiographic results (values 0,1,2)  | int64 |
# |09| **Max HR**   | maximum heart rate achieved | int64 |
# |10| **Exercise angina**   | exercise induced angina (1 = yes; 0 = no) | int64 |
# |11| **ST depression**   | ST depression induced by exercise relative to rest | float64 |
# |12| **Slope of ST**   | the slope of the peak exercise ST segment | int64 |
# |13| **Number of vessels fluro**   | number of major vessels (0-3) colored by flourosopy | int64 |
# |14| **Thallium**   | 1 = normal; 2 = fixed defect; 3 = reversable defect| int64 |
# |14| **Heart Disease**   | It is object valued Absence = no disease and Presence = disease. | object |
#
#
# ---
#
# - Data types of all the features look appropriate.
# - There are no missing values in any features.
# - Number of duplicated rows: 0 (0.0% of total rows)
# - Memory usage of the DataFrame: 103635.34 KB (approx)

# %%
def get_proportion_of_categorical_values(df, column_name):
    """
    This function calculates the proportion of each unique value in a categorical column.

    Parameters:
    df (pd.DataFrame): The DataFrame containing the categorical column.
    column_name (str): The name of the categorical column for which to calculate proportions.

    Returns:
    None (prints proportions for each column).
    """
    not_in_list2 = list(set(column_name) - set(df.columns))

    # Checking if the specified column is in the DataFrame
    if len(not_in_list2) > 0:
        raise ValueError(f"Column(s) '{', '.join(not_in_list2)}' not found in the DataFrame.")

    # Calculating the proportion of each unique value in the specified column
    for col in column_name:
        proportions = df[col].value_counts(normalize=True) * 100  # Multiplying by 100 to get percentages
        print(f"\nProportions for column '{col}' in %:")
        print(proportions)
        print("-" * 50)  # Adding a separator for better readability

# %%
get_proportion_of_categorical_values(data, categorical_columns)
# Out:
# Proportions for column 'Heart Disease' in %:
# Heart Disease
# Absence    55.16603
# Presence   44.83397
# Name: proportion, dtype: float64
# --------------------------------------------------

# %%
test_data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Uni-variate Analysis.</u></li>
# </ul>
# </p>
#
# ---

# %%
total_datapoints = data.shape[0]
print(f"Total number of data points: {total_datapoints}")
# Out:
# Total number of data points: 630000

# %%
def plot_univariate_distribution(df, column, plot_type="histogram", plot_width=12, plot_height=4):
    """
    This function plots the univariate distribution of a specified column in the DataFrame 
    using the specified plot type (histogram, boxplot, or countplot). It also calculates 
    and prints the Interquartile Range (IQR) of the specified column.

    Parameters:
    df (pd.DataFrame): The DataFrame containing the data.
    column (str): The name of the column to plot.
    plot_type (str): The type of plot to create ("histogram" or "boxplot" or "countplot").

    Returns:
    None
    """

    fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(plot_width, plot_height))

    sns.kdeplot(df[column], shade=True, color='blue', ax=ax1)
    ax1.set_title(f'Distribution of {column.capitalize()}')
    ax1.set_xlabel(column.capitalize())
    #plt.figure(figsize=(6, 4))
    
    #plt.title(f'Distribution of {column.capitalize()}')
    #plt.xlabel(column.capitalize())

    if plot_type != "boxplot":
        if plot_type == "histogram":
            ax2 = sns.histplot(df[column], kde=True, color='blue')
            ax2.set_ylabel('Frequency')
            ax2.set_title(f'{plot_type.capitalize()} of {column.capitalize()}')
            #plt.ylabel('Frequency')
            #plt.title(f'{plot_type.capitalize()} of {column.capitalize()}')
        elif plot_type == "countplot":
            ax2 = sns.countplot(x=df[column], palette='magma')
            ax2.set_ylabel('Count')
            ax2.set_title(f'{plot_type.capitalize()} of {column.capitalize()}')
        else:
            raise ValueError("Invalid plot type. Use 'histogram' or 'boxplot' or 'countplot'.")

        for p in ax2.patches:
            percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
            x = p.get_x() + p.get_width()/5
            y = p.get_y() + p.get_height()
            ax2.annotate(percentage, (x, y))

    else:
        ax2 = sns.boxplot(x=df[column], palette='magma')
        ax2.set_title(f'{plot_type.capitalize()} of {column.capitalize()}')


    
    ax2.set_xlabel(column.capitalize())
    plt.show()

    iqr_column = df[column].quantile(0.75) - df[column].quantile(0.25)
    print(f" IQR of {column.capitalize()}: {iqr_column}")

# %%
numerical_columns, categorical_columns
# Out:
# (['id',
#   'Age',
#   'Sex',
#   'Chest pain type',
#   'BP',
#   'Cholesterol',
#   'FBS over 120',
#   'EKG results',
#   'Max HR',
#   'Exercise angina',
#   'ST depression',
#   'Slope of ST',
#   'Number of vessels fluro',
#   'Thallium'],
#  ['Heart Disease'])

# %%
plot_univariate_distribution(data, column="Age", plot_type="boxplot")
# Out:
#  IQR of Age: 12.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - Min value is around 29, 25% data is around 48, 50% data is around 54 and 75% data is 60.
# - Data is left skewed or better to say having outlier at the left side of the median.
#
# Though data point wise we can say that it's having outlier, but w.r.t. our problem statement we cannot say that we will not check a person is prone to heart disease or not if that person is less than 30 or like that. So we can ignore outlier treatment for this feature.

# %%
plot_univariate_distribution(data, column="Sex", plot_type="countplot")
# Out:
#  IQR of Sex: 1.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - Data is biased
# - 28.53% data is for female denoted with value 0
# - 71.47% data is for male denoted with value 1

# %%
plot_univariate_distribution(data, column="Chest pain type", plot_type="countplot")
# Out:
#  IQR of Chest pain type: 1.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - Type 1 Chest pain data is 4.54%
# - Type 2 Chest pain data is 11.90%
# - Type 3 Chest pain data is 31.31%
# - Type 4 Chest pain data is 52.25%
# - Data is biased w.r.t. to categorization

# %%
plot_univariate_distribution(data, column="BP", plot_type="boxplot")
# Out:
#  IQR of Bp: 20.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - 25% data is within the scale of 120
# - 50% data is within the scale of 130
# - 75% data is within the scale of 140
# - Data is right-skewed and having outliers. Need further analysis

# %%
plot_univariate_distribution(data, column="Cholesterol", plot_type="boxplot")
# Out:
#  IQR of Cholesterol: 46.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - 25% data is within the scale of 223
# - 50% data is within the scale of 243
# - 75% data is within the scale of 269
# - Data is spread in both the tail ends and having outliers at both end. Need further analysis.

# %%
plot_univariate_distribution(data, column="FBS over 120", plot_type="countplot")
# Out:
#  IQR of Fbs over 120: 0.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - Only 8% patient is having Fasting blood suger level > 120 mg/dl
# - Remaining 92% patient don't have Fasting blood suger level > 120 mg/dl
# - This categorical feature is also biased based on the distribution of data for Fasting blood suger level > 120 mg/dl

# %%
plot_univariate_distribution(data, column="EKG results", plot_type="countplot")
# Out:
#  IQR of Ekg results: 2.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - Resting Electrocardiographic result is having 3 values (0, 1, 2)
# - 50.81% data corresponds to value 0
# - 0.21% data corresponds to value 1
# - 48.98% data corresponds to value 2
# - Distribution of data among this 3 values is not balanced

# %%
plot_univariate_distribution(data, column="Max HR", plot_type="boxplot")
# Out:
#  IQR of Max hr: 24.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - Minimum value is 71
# - 25% data is within 142
# - 50% data is within 157
# - 75% data is within 166
# - Data is left-skewed and having outliers, need further analysis.

# %%
plot_univariate_distribution(data, column="Exercise angina", plot_type="countplot")
# Out:
#  IQR of Exercise angina: 1.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - For exercise induced angina we are having 27.37% people as yes (denoted by value 1)
# - Remaining 72.63% people don't have exercise induced angina
# - Data biased

# %%
plot_univariate_distribution(data, column="ST depression", plot_type="boxplot")
# Out:
#  IQR of St depression: 1.4

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - 25% data is on the scale of 0
# - 50% data is on the scale of 0.1
# - 75% data is on the scale of 1.4
# - Data is right-skewed and having lot's of outlier, need further analysis.

# %%
plot_univariate_distribution(data, column="Slope of ST", plot_type="countplot")
# Out:
#  IQR of Slope of st: 1.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - 56.87% data is on the scale of 1
# - 40.67% data is on the scale of 2
# - 2.46% data is on the scale of 3
# - Data is biased w.r.t. distribution of data

# %%
plot_univariate_distribution(data, column="Number of vessels fluro", plot_type="countplot")
# Out:
#  IQR of Number of vessels fluro: 1.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - 70.77% data corresponding to the value of 0
# - 16.98% data corresponding to the value of 1
# - 8.62% data corresponding to the value of 2
# - 3.63% data corresponding to the value of 3

# %%
plot_univariate_distribution(data, column="Thallium", plot_type="countplot")
# Out:
#  IQR of Thallium: 4.0

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - 59.09% data corresponding to the value of 3
# - 1.74% data corresponding to the value of 6
# - 39.17% data corresponding to the value of 7

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Bi-variate Analysis.</u></li>
# </ul>
# </p>
#
# ---

# %%
def plot_bivariate_relationship(df, x_column, y_column, x_label=None, y_label=None, plot_type="scatter", plot_width=6, plot_height=4):
    """
    This function plots the bivariate relationship between two specified columns in the DataFrame.

    Parameters:
    df (pd.DataFrame): The DataFrame containing the data.
    x_column (str): The name of the column to be plotted on the x-axis.
    y_column (str): The name of the column to be plotted on the y-axis.
    x_label (str): The label for the x-axis.
    y_label (str): The label for the y-axis.
    plot_type (str): The type of plot to create ("scatter" or "line" or "crosstab" or "boxplot").
    plot_width (int): The width of the plot in inches.
    plot_height (int): The height of the plot in inches.

    Returns:
    None
    """

    fig = plt.figure(figsize=(plot_width, plot_height))

    if plot_type == "scatter":
        ax = sns.scatterplot(x=df[x_column], y=df[y_column], color='blue')

        plt.title(f'Scatter Plot of {y_column.capitalize() if y_label is None else y_label.capitalize()} vs {x_column.capitalize() if x_label is None else x_label.capitalize()}')

    elif plot_type == "line":
        ax = sns.lineplot(x=df[x_column], y=df[y_column], color='blue')

        plt.title(f'Line Plot of {y_column.capitalize() if y_label is None else y_label.capitalize()} vs {x_column.capitalize() if x_label is None else x_label.capitalize()}')

    elif plot_type == "countplot":
        ax = sns.countplot(x=df[x_column], hue=df[y_column], palette='magma')

        for p in ax.patches:
            percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
            x = p.get_x() + p.get_width()/5
            y = p.get_y() + p.get_height()
            ax.annotate(percentage, (x, y))

        plt.title(f'Count Plot of {y_column.capitalize() if y_label is None else y_label.capitalize()} vs {x_column.capitalize() if x_label is None else x_label.capitalize()}')
    elif plot_type == "crosstab":
        crosstab = pd.crosstab(df[x_column], df[y_column])
        ax = crosstab.plot(kind='bar', stacked=True, figsize=fig)

        for p in ax.patches:
            percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
            x = p.get_x() + p.get_width()/5
            y = p.get_y() + p.get_height()
            ax.annotate(percentage, (x, y))

        plt.title(f'Cross-tabulation of {y_column.capitalize() if y_label is None else y_label.capitalize()} vs {x_column.capitalize() if x_label is None else x_label.capitalize()}')

    elif plot_type == "boxplot":
        ax = sns.boxplot(x=df[x_column], y=df[y_column])

        plt.title(f'Box Plot of {y_column.capitalize() if y_label is None else y_label.capitalize()} vs {x_column.capitalize() if x_label is None else x_label.capitalize()}')

    else:
        raise ValueError("Invalid plot type. Use 'scatter' or 'line'  or 'crosstab' or 'boxplot'.")


    plt.ylabel(y_column.capitalize() if y_label is None else y_label.capitalize())
    plt.xlabel(x_column.capitalize() if x_label is None else x_label.capitalize())

    plt.grid(visible=True)
    plt.show()

# %%
plot_bivariate_relationship(data, x_column="Heart Disease", y_column="BP", plot_type="boxplot", x_label="Heart Disease", y_label="BP")

# %%
plot_bivariate_relationship(data, x_column="Heart Disease", y_column="Cholesterol", plot_type="boxplot", x_label="Heart Disease", y_label="Cholesterol")

# %%
plot_bivariate_relationship(data, x_column="Heart Disease", y_column="Max HR", plot_type="boxplot", x_label="Heart Disease", y_label="Max HR")

# %%
plot_bivariate_relationship(data, x_column="Heart Disease", y_column="ST depression", plot_type="boxplot", x_label="Heart Disease", y_label="ST depression")

# %% [markdown]
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Perform Data Wrangling.</u></li>
# </ul>
# </p>
#
# ---

# %%
def copy_dataframe(df):
    """
    This function creates and returns a copy of the given DataFrame
    to ensure that the original DataFrame remains unchanged during analysis.
    Also it removes duplicate data points if there are any in the DataFrame.

    Parameters:
    df (pd.DataFrame): The DataFrame to copy.

    Returns:
    pd.DataFrame: A copy of the input DataFrame.
    """
    df_copy = df.copy()

    # dropping duplicate data and keeping the first occurrence of each duplicate
    df_copy.drop_duplicates(inplace=True, keep='first')
    return df_copy

# %%
clean_data = copy_dataframe(data)

clean_test_data = copy_dataframe(test_data)

clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Age                      630000 non-null  int64
#  2   Sex                      630000 non-null  int64
#  3   Chest pain type          630000 non-null  int64
#  4   BP                       630000 non-null  int64
#  5   Cholesterol              630000 non-null  int64
#  6   FBS over 120             630000 non-null  int64
#  7   EKG results              630000 non-null  int64
#  8   Max HR                   630000 non-null  int64
#  9   Exercise angina          630000 non-null  int64
#  10  ST depression            630000 non-null  float64
#  11  Slope of ST              630000 non-null  int64
#  12  Number of vessels fluro  630000 non-null  int64
#  13  Thallium                 630000 non-null  int64
# ...

# %%
bounds =pd.DataFrame(columns=["Column", "Lower Bound", "Upper Bound"])
bounds
# Out:
# Empty DataFrame
# Columns: [Column, Lower Bound, Upper Bound]
# Index: []

# %%
def winsorize_iqr_by_class(df, group_col='Heart Disease', cols=None, k=1.5):
    """
    This function performs winsorization on the specified columns of a DataFrame based on the 
    Interquartile Range (IQR) for each class in a specified grouping column.

    Parameters:
    df (pd.DataFrame): The DataFrame to be processed.
    group_col (str): The name of the column to group by (default is 'Heart Disease').
    cols (list): The list of columns to be winsorized (default is None, which means all columns).
    k (float): The multiplier for the IQR (default is 1.5).

    Returns:
    pd.DataFrame: A DataFrame with the specified columns winsorized based on the IQR for each class.
    """

    if cols is None:
        cols = df.columns.tolist()

    bounds =pd.DataFrame(columns=["Column", "Lower Bound", "Upper Bound"])

    for col in cols:
        # Grouping the DataFrame by the specified grouping column and calculating the IQR for each group
        grouped = df.groupby(group_col)[col]
        Q1 = grouped.transform(lambda x: x.quantile(0.25))
        Q3 = grouped.transform(lambda x: x.quantile(0.75))
        IQR = Q3 - Q1

        # Calculating the lower and upper bounds for winsorization
        lower_bound = Q1 - k * IQR
        upper_bound = Q3 + k * IQR

        sub_bounds = pd.DataFrame({
            'Column': col,
            'Lower Bound': lower_bound,
            'Upper Bound': upper_bound
        })
        
        if len(bounds) == 0:
            bounds = sub_bounds
        else:
            if col not in bounds['Column'].values:
                bounds = pd.concat([bounds, sub_bounds], ignore_index=True)

        # Applying winsorization to the specified column based on the calculated bounds
        df[col] = np.where(df[col] < lower_bound, lower_bound, np.where(df[col] > upper_bound, upper_bound, df[col]))

    return df, bounds.drop_duplicates(keep='first')

# %%
winsorization_columns = ['BP', 'Cholesterol', 'Max HR', 'ST depression']
clean_data, bounds = winsorize_iqr_by_class(clean_data, group_col='Heart Disease', cols=winsorization_columns, k=1.5)

# %%
def winsorize_test_data(df,cols=None, bounds=None):
    """
    This function performs winsorization on the specified columns of a DataFrame based on the 
    Interquartile Range (IQR) for each class in a specified grouping column.

    Parameters:
    df (pd.DataFrame): The DataFrame to be processed.
    cols (list): The list of columns to be winsorized (default is None, which means all columns).
    bounds (pd.DataFrame): A DataFrame containing the lower and upper bounds for winsorization for each column.

    Returns:
    pd.DataFrame: A DataFrame with the specified columns winsorized based on the IQR for each class.
    """

    if cols is None:
        cols = df.columns.tolist()
        print(cols)

    if bounds is None:
        raise ValueError("Bounds must be provided for winsorization.")
    else:
        print(bounds)

    for col in cols:
        # Finding the corresponding bounds for the current column
        #col_bounds = next((b for b in bounds if b['Column'].iloc[0] == col), None)
        col_bounds = bounds[bounds['Column'] == col].iloc[0] if not bounds.empty else None

        if col_bounds is not None:
            lower_bound = col_bounds['Lower Bound']
            upper_bound = col_bounds['Upper Bound']

            # Applying winsorization to the specified column based on the calculated bounds
            df[col] = np.where(df[col] < lower_bound, lower_bound, np.where(df[col] > upper_bound, upper_bound, df[col]))
        else:
            raise ValueError(f"No bounds found for column '{col}'.")

    return df

# %%
clean_test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270000 entries, 0 to 269999
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       270000 non-null  int64
#  1   Age                      270000 non-null  int64
#  2   Sex                      270000 non-null  int64
#  3   Chest pain type          270000 non-null  int64
#  4   BP                       270000 non-null  int64
#  5   Cholesterol              270000 non-null  int64
#  6   FBS over 120             270000 non-null  int64
#  7   EKG results              270000 non-null  int64
#  8   Max HR                   270000 non-null  int64
#  9   Exercise angina          270000 non-null  int64
#  10  ST depression            270000 non-null  float64
#  11  Slope of ST              270000 non-null  int64
#  12  Number of vessels fluro  270000 non-null  int64
#  13  Thallium                 270000 non-null  int64
# ...

# %%
clean_test_data = winsorize_test_data(clean_test_data, cols=winsorization_columns, bounds=bounds)
# Out:
#                 Column  Lower Bound  Upper Bound
# 0                   BP     90.00000    170.00000
# 630000     Cholesterol    161.50000    333.50000
# 630001     Cholesterol    150.00000    334.00000
# 1260000         Max HR     85.00000    205.00000
# 1260001         Max HR    122.00000    202.00000
# 1890000  ST depression     -2.70000      4.50000
# 1890001  ST depression     -0.75000      1.25000

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

sns.boxplot(x=data['Heart Disease'], y=data['BP'],width=0.9,palette='pastel', ax=ax1)
ax1.set_title('Box Plot of BP by Heart Disease (Before Winsorization)')
ax1.set_xlabel('Heart Disease')
ax1.set_ylabel('BP')

sns.boxplot(x=clean_data['Heart Disease'], y=clean_data['BP'],width=0.9,palette='pastel', ax=ax2)
ax2.set_title('Box Plot of BP by Heart Disease (After Winsorization)')
ax2.set_xlabel('Heart Disease')
ax2.set_ylabel('BP')
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

sns.boxplot(x=data['Heart Disease'], y=data['Cholesterol'],width=0.9,palette='pastel', ax=ax1)
ax1.set_title('Box Plot of Cholesterol by Heart Disease (Before Winsorization)')
ax1.set_xlabel('Heart Disease')
ax1.set_ylabel('Cholesterol')

sns.boxplot(x=clean_data['Heart Disease'], y=clean_data['Cholesterol'],width=0.9,palette='pastel', ax=ax2)
ax2.set_title('Box Plot of Cholesterol by Heart Disease (After Winsorization)')
ax2.set_xlabel('Heart Disease')
ax2.set_ylabel('Cholesterol')
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

sns.boxplot(x=data['Heart Disease'], y=data['Max HR'],width=0.9,palette='pastel', ax=ax1)
ax1.set_title('Box Plot of Max HR by Heart Disease (Before Winsorization)')
ax1.set_xlabel('Heart Disease')
ax1.set_ylabel('Max HR')

sns.boxplot(x=clean_data['Heart Disease'], y=clean_data['Max HR'],width=0.9,palette='pastel', ax=ax2)
ax2.set_title('Box Plot of Max HR by Heart Disease (After Winsorization)')
ax2.set_xlabel('Heart Disease')
ax2.set_ylabel('Max HR')
plt.show()

# %%
fig, (ax1,ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

sns.boxplot(x=data['Heart Disease'], y=data['ST depression'],width=0.9,palette='pastel', ax=ax1)
ax1.set_title('Box Plot of ST Depression by Heart Disease (Before Winsorization)')
ax1.set_xlabel('Heart Disease')
ax1.set_ylabel('ST Depression')

sns.boxplot(x=clean_data['Heart Disease'], y=clean_data['ST depression'],width=0.9,palette='pastel', ax=ax2)
ax2.set_title('Box Plot of ST Depression by Heart Disease (After Winsorization)')
ax2.set_xlabel('Heart Disease')
ax2.set_ylabel('ST Depression')
plt.show()

# %%
def categorize_bp(bp):
    """
    Blood Pressure Categorization (AHA Guidelines)
    0: Normal (<120), 1: Elevated (120-129), 2: Stage 1 HTN (130-139), 3: Stage 2 HTN (>=140)
    """
    if bp < 120:
        return 'Normal'
    elif 120 <= bp < 130:
        return 'Elevated'
    elif 130 <= bp < 140:
        return 'Stage 1 HTN'
    else:
        return 'Stage 2 HTN'

# %%
# Convert 'Heart Disease' from categorical to numerical (1 for Presence, 0 for Absence)
clean_data['Heart_Disease_Target'] = clean_data['Heart Disease'].map({'Presence': 1, 'Absence': 0})

# Heart Rate Reserve (HRR)
# Clinical insight: Estimated Max HR is roughly (220 - Age). 
# The difference between this and the patient's actual Max HR can indicate cardiovascular fitness.
clean_data['Expected_Max_HR'] = 220 - clean_data['Age']
clean_data['HR_Reserve'] = clean_data['Expected_Max_HR'] - clean_data['Max HR']

#Blood Pressure Categorization (AHA Guidelines)
#    0: Normal (<120), 1: Elevated (120-129), 2: Stage 1 HTN (130-139), 3: Stage 2 HTN (>=140)
clean_data['BP_Category'] = clean_data['BP'].apply(categorize_bp)

# %%
def feature_engineering_test_data(df):
    """
    This function performs feature engineering on the test data by creating new features based on the existing ones.

    Parameters:
    df (pd.DataFrame): The test DataFrame to be processed.

    Returns:
    pd.DataFrame: A DataFrame with the new features added.
    """

    # Heart Rate Reserve (HRR)
    # Clinical insight: Estimated Max HR is roughly (220 - Age). 
    # The difference between this and the patient's actual Max HR can indicate cardiovascular fitness.
    df['Expected_Max_HR'] = 220 - df['Age']
    df['HR_Reserve'] = df['Expected_Max_HR'] - df['Max HR']

    # Blood Pressure Categorization (AHA Guidelines)
    # 0: Normal (<120), 1: Elevated (120-129), 2: Stage 1 HTN (130-139), 3: Stage 2 HTN (>=140)
    df['BP_Category'] = df['BP'].apply(categorize_bp)

    return df

# %%
clean_test_data = feature_engineering_test_data(clean_test_data)

# %%
clean_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630000 entries, 0 to 629999
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       630000 non-null  int64
#  1   Age                      630000 non-null  int64
#  2   Sex                      630000 non-null  int64
#  3   Chest pain type          630000 non-null  int64
#  4   BP                       630000 non-null  float64
#  5   Cholesterol              630000 non-null  float64
#  6   FBS over 120             630000 non-null  int64
#  7   EKG results              630000 non-null  int64
#  8   Max HR                   630000 non-null  float64
#  9   Exercise angina          630000 non-null  int64
#  10  ST depression            630000 non-null  float64
#  11  Slope of ST              630000 non-null  int64
#  12  Number of vessels fluro  630000 non-null  int64
# ...

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Multivariate Analysis</u></li>
# </ul>
# </p>
#
# ---

# %%
corr_cols = ['Age', 'BP', 'Cholesterol', 'Max HR', 'ST depression', 'Expected_Max_HR', 'HR_Reserve', 'Heart_Disease_Target']

corr_matrix = clean_data[corr_cols].corr()

# %%
corr_matrix
# Out:
#                           Age       BP  Cholesterol   Max HR  ST depression  \
# Age                   1.00000 -0.00367      0.02004 -0.09902        0.11443
# BP                   -0.00367  1.00000     -0.00438  0.00364       -0.00373
# Cholesterol           0.02004 -0.00438      1.00000 -0.04991        0.04961
# Max HR               -0.09902  0.00364     -0.04991  1.00000       -0.25719
# ST depression         0.11443 -0.00373      0.04961 -0.25719        1.00000
# Expected_Max_HR      -1.00000  0.00367     -0.02004  0.09902       -0.11443
# HR_Reserve           -0.32051 -0.00194      0.03920 -0.91085        0.19736
# Heart_Disease_Target  0.21209 -0.00395      0.08424 -0.44826        0.48682
#
#                       Expected_Max_HR  HR_Reserve  Heart_Disease_Target
# Age                          -1.00000    -0.32051               0.21209
# BP                            0.00367    -0.00194              -0.00395
# ...

# %%
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - Looking at the heatmap, ST depression has the highest positive correlation with Heart Disease.
# - Conversely, Max HR shows a negative correlation, meaning lower maximum heart rates achieved during exercise are associated with higher disease risk.
# - HR_Reserve which indicate the cardiovascular fitness, has the 2nd highest positive correlation with Heart Disease.
# - Age has the 3rd highest positive correlation with Heart Disease.

# %%
get_proportion_of_categorical_values(clean_data, ['BP_Category'])
# Out:
# Proportions for column 'BP_Category' in %:
# BP_Category
# Stage 2 HTN   31.77492
# Elevated      27.19476
# Stage 1 HTN   24.59429
# Normal        16.43603
# Name: proportion, dtype: float64
# --------------------------------------------------

# %%
le = LabelEncoder()
clean_data['BP_Category_encoded'] = le.fit_transform(clean_data['BP_Category'].astype(str))
distinct_pairs = clean_data[['BP_Category','BP_Category_encoded']].drop_duplicates().reset_index(drop=True)
print(distinct_pairs)
# Out:
#    BP_Category  BP_Category_encoded
# 0  Stage 2 HTN                    3
# 1     Elevated                    0
# 2  Stage 1 HTN                    2
# 3       Normal                    1

# %%
def encode_BP_Category(df, distinct_pairs):
    """
    This function encodes the 'BP_Category' column in the DataFrame using the provided distinct pairs of categories and their corresponding encoded values.

    Parameters:
    df (pd.DataFrame): The DataFrame containing the 'BP_Category' column to be encoded.
    distinct_pairs (pd.DataFrame): A DataFrame containing the distinct pairs of 'BP_Category' and their corresponding encoded values.

    Returns:
    pd.DataFrame: A DataFrame with the 'BP_Category' column encoded as 'BP_Category_encoded'.
    """

    # Creating a mapping dictionary from the distinct pairs DataFrame
    mapping_dict = dict(zip(distinct_pairs['BP_Category'], distinct_pairs['BP_Category_encoded']))

    # Encoding the 'BP_Category' column using the mapping dictionary
    df['BP_Category_encoded'] = df['BP_Category'].map(mapping_dict)

    return df

# %%
clean_test_data = encode_BP_Category(clean_test_data, distinct_pairs)

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">2. Decision Tree Parameters:</h3>

# %%
X = clean_data.drop(columns=['id', 'Heart Disease', 'Heart_Disease_Target', 'BP_Category'])
y = clean_data['Heart_Disease_Target']

clean_data.shape, X.shape, y.shape
# Out:
# ((630000, 20), (630000, 16), (630000,))

# %%
X_main, X_test, y_main, y_test = train_test_split(X, y, test_size=0.15, random_state=42, stratify=y)

validation_ratio = 0.15
remaining_ratio = 1.0 - 0.15
adj_validation_size = validation_ratio / remaining_ratio

X_train, X_val, y_train, y_val = train_test_split(X_main, y_main, test_size=adj_validation_size, random_state=42, stratify=y_main)

print(f"Training set size: {len(X_train)} samples")
print(f"Validation set size: {len(X_val)} samples")
print(f"Test set size: {len(X_test)} samples")
# Out:
# Training set size: 441000 samples
# Validation set size: 94500 samples
# Test set size: 94500 samples

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Note:
#
# - I've tried SMOTEEN sampling technique to balance the minimal difference in the Heart_Disease_Target column.
#   However it came to my observation that on doing so it was actually introducing some artificial noise in the dataset.
#   So that's the reason I've removed that section of code.

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">3. Building the Decision Tree:</h3>

# %%
dtree_model = DecisionTreeClassifier(random_state=42, criterion='entropy', max_depth=5, splitter='best')
dtree_model.fit(X_train_scaled, y_train)
dtree_model
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, random_state=42)

# %%
plt.figure(figsize=(20,10)) # Adjust figure size for better readability
plot_tree(dtree_model, 
          filled=True, 
          feature_names=X.columns, 
          class_names=clean_data['Heart_Disease_Target'].map({1: 'Presence', 0: 'Absence'}).values,
          rounded=True, 
          precision=3,
          fontsize=10) # Customize display options
plt.show()

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">4. Model Evaluation:</h3>

# %%
y_val_pred = dtree_model.predict(X_val_scaled)
accuracy = accuracy_score(y_val, y_val_pred)
print("Validation Accuracy:")
accuracy
# Out:
# Validation Accuracy:
# 0.8841375661375661

# %%
print("Validation Classification Report for Decision Tree:")
print(classification_report(y_val, y_val_pred))
# Out:
# Validation Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.90     52132
#            1       0.91      0.82      0.86     42368
#
#     accuracy                           0.88     94500
#    macro avg       0.89      0.88      0.88     94500
# weighted avg       0.89      0.88      0.88     94500

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">5. Hyperparameter Tuning and Optimization:</h3>

# %%
# Define the K-Fold strategy
kf = KFold(n_splits=5, shuffle=True, random_state=42)

best_depth = 0
best_score = 0

# Iterate through a range of values for max_depth
for depth in range(1, 11):
    model = DecisionTreeClassifier(max_depth=depth, random_state=42)
    
    # Perform cross-validation and get average accuracy
    scores = cross_val_score(model, X_train_scaled, y_train, cv=kf)
    avg_score = np.mean(scores)
    
    print(f"Depth {depth}: Avg Accuracy = {avg_score:.4f}")
    
    # Track the best performing parameter
    if avg_score > best_score:
        best_score = avg_score
        best_depth = depth

print(f"\nBest Parameter Found Manually: max_depth={best_depth} (Score: {best_score:.4f})")
# Out:
# Depth 1: Avg Accuracy = 0.8049
# Depth 2: Avg Accuracy = 0.8503
# Depth 3: Avg Accuracy = 0.8634
# Depth 4: Avg Accuracy = 0.8835
# Depth 5: Avg Accuracy = 0.8869
# Depth 6: Avg Accuracy = 0.8967
# Depth 7: Avg Accuracy = 0.8999
# Depth 8: Avg Accuracy = 0.9054
# Depth 9: Avg Accuracy = 0.9075
# Depth 10: Avg Accuracy = 0.9095
#
# Best Parameter Found Manually: max_depth=10 (Score: 0.9095)

# %%
# 1. Define the parameters and their potential values
param_grid = {
    'max_depth': [3, 5, 7, 8, 10],
    'min_samples_split': [2, 5, 7, 10],
    'criterion': ['gini', 'entropy']
}

# 2. Initialize the Grid Search with the model and 5-fold CV
# n_jobs=-1 uses all available processor cores for speed
grid_search = GridSearchCV(DecisionTreeClassifier(random_state=159), 
                           param_grid, 
                           cv=5, 
                           scoring='f1',
                           n_jobs=-1)

# Note:
# - We are using 'f1' as the scoring metric to balance precision and recall, especially important for imbalanced datasets.
# - The 'scoring' parameter of GridSearchCV must be a string among 
# {'recall_weighted', 'normalized_mutual_info_score', 'precision_weighted', 'homogeneity_score', 'positive_likelihood_ratio', 
# 'v_measure_score', 'f1_macro', 'average_precision', 'roc_auc_ovr_weighted', 'roc_auc_ovo_weighted', 'precision_macro', 
# 'roc_auc', 'jaccard_micro', 'precision_samples', 'adjusted_mutual_info_score', 'rand_score', 'd2_absolute_error_score', 
# 'd2_brier_score', 'neg_log_loss', 'neg_median_absolute_error', 'neg_mean_squared_error', 'r2', 'recall_macro', 'roc_auc_ovo', 
# 'adjusted_rand_score', 'f1_samples', 'roc_auc_ovr', 'recall_micro', 'neg_brier_score', 'accuracy', 'jaccard_macro', 'jaccard', 
# 'neg_root_mean_squared_error', 'neg_root_mean_squared_log_error', 'precision', 'jaccard_samples', 'neg_mean_squared_log_error', 
# 'f1', 'recall', 'f1_weighted', 'f1_micro', 'mutual_info_score', 'balanced_accuracy', 'precision_micro', 'explained_variance', 
# 'fowlkes_mallows_score', 'neg_mean_absolute_percentage_error', 'matthews_corrcoef', 'completeness_score', 'd2_log_loss_score', 
# 'neg_mean_gamma_deviance', 'neg_negative_likelihood_ratio', 'neg_max_error', 'recall_samples', 'jaccard_weighted', 
# 'top_k_accuracy', 'neg_mean_poisson_deviance', 'neg_mean_absolute_error'}

# 3. Fit the search to the data
grid_search.fit(X_train_scaled, y_train)

# 4. Output the results
print(f"Best Parameters Found by GridSearch: {grid_search.best_params_}")
print(f"Best Cross-Validation F1 Score: {grid_search.best_score_:.4f}")
print(f"Scorer Used: {grid_search.scorer_}")

# You can now use the best model directly
best_model = grid_search.best_estimator_
# Out:
# Best Parameters Found by GridSearch: {'criterion': 'gini', 'max_depth': 10, 'min_samples_split': 10}
# Best Cross-Validation F1 Score: 0.8970
# Scorer Used: make_scorer(f1_score, response_method='predict', average=binary)

# %%
X_train_scaled.shape, X_test_scaled.shape, X_val_scaled.shape
# Out:
# ((441000, 16), (94500, 16), (94500, 16))

# %%
# 1. Convert grid search results to a DataFrame
results_df = pd.DataFrame(grid_search.cv_results_)

# 2. Filter for one criterion (e.g., 'entropy') to visualize the effect of max_depth and min_samples_split
viz_data = results_df[results_df['param_criterion'] == 'entropy']

# 3. Pivot the data: Rows = max_depth, Columns = min_samples_split 
pivot_table = viz_data.pivot(index='param_max_depth', 
                             columns='param_min_samples_split', 
                             values='mean_test_score')

# 4. Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(pivot_table, annot=True, cmap='viridis', fmt='.4f')
plt.title('Grid Search Accuracy: max_depth vs min_samples_split (Gini)')
plt.show()

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - For parameter 'max_depth':
#     - max_depth = 5 Accuracy =0.8665
#     - max_depth = 7 Accuracy =0.8838
#     - max_depth = 8 Accuracy =0.8878
#     - max_depth = 10 Accuracy =0.8969
#
#   From the above data we can see there is a increase or better to forming a plateau with increasing value of >= 0.0040.
#   Though this number is not significant in close interval but if we set a jumping interval then
#   it will show a significant increase of > 0.01.
#
#   Still now it's not showing any or very negligible symptom of overfitting, but need to analyze further.

# %%
# 1. Get predicted probabilities for the positive class (usually index 1)
# We will use the separate validation set (X_val_scaled) that the model hasn't seen
y_probs = best_model.predict_proba(X_val_scaled)[:, 1]

# 2. Calculate the AUC score
auc_value = roc_auc_score(y_val, y_probs)
print(f"AUC Score on Validation Set: {auc_value:.4f}")

# 3. Plot the ROC Curve
plt.figure(figsize=(8, 6))
RocCurveDisplay.from_estimator(best_model, X_val_scaled, y_val, color="darkorange")

# Add a diagonal dashed line (representing a random guess / 0.5 AUC)
plt.plot([0, 1], [0, 1], color="navy", lw=2, linestyle="--")

plt.title(f"ROC Curve (AUC = {auc_value:.2f})")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.grid(True)
plt.show()
# Out:
# AUC Score on Validation Set: 0.9692

# %%
y_train_pred = best_model.predict(X_train_scaled)
accuracy_train = accuracy_score(y_train, y_train_pred)
print(f"Training Accuracy: {accuracy_train:.4f}")

print("Validation Classification Report for Decision Tree:")
print(classification_report(y_train, y_train_pred))
# Out:
# Training Accuracy: 0.9108
# Validation Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92    243282
#            1       0.92      0.88      0.90    197718
#
#     accuracy                           0.91    441000
#    macro avg       0.91      0.91      0.91    441000
# weighted avg       0.91      0.91      0.91    441000

# %%
cm = confusion_matrix(y_train, y_train_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, 
            xticklabels=['Predicted Absence', 'Predicted Presence'], 
            yticklabels=['Actual Absence', 'Actual Presence'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
y_val_pred1= best_model.predict(X_val_scaled)
accuracy_val = accuracy_score(y_val, y_val_pred1)
print(f"Validation Accuracy: {accuracy_val:.4f}")


print("Validation Classification Report for Decision Tree:")
print(classification_report(y_val, y_val_pred1))
# Out:
# Validation Accuracy: 0.9093
# Validation Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     52132
#            1       0.91      0.88      0.90     42368
#
#     accuracy                           0.91     94500
#    macro avg       0.91      0.91      0.91     94500
# weighted avg       0.91      0.91      0.91     94500

# %%
cm = confusion_matrix(y_val, y_val_pred1)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False, 
            xticklabels=['Predicted Absence', 'Predicted Presence'], 
            yticklabels=['Actual Absence', 'Actual Presence'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
y_test_pred1 = best_model.predict(X_test_scaled)
accuracy_test = accuracy_score(y_test, y_test_pred1)
print(f"Test Accuracy: {accuracy_test:.4f}")


print("Test Classification Report for Decision Tree:")
print(classification_report(y_test, y_test_pred1))
# Out:
# Test Accuracy: 0.9109
# Test Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.91      0.93      0.92     52132
#            1       0.92      0.88      0.90     42368
#
#     accuracy                           0.91     94500
#    macro avg       0.91      0.91      0.91     94500
# weighted avg       0.91      0.91      0.91     94500

# %%
cm1 = confusion_matrix(y_test, y_test_pred1)
plt.figure(figsize=(6, 4))
sns.heatmap(cm1, annot=True, fmt='d', cmap='Blues', cbar=False, 
            xticklabels=['Predicted Absence', 'Predicted Presence'], 
            yticklabels=['Actual Absence', 'Actual Presence'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
accuracy_train, accuracy_val, accuracy_test
# Out:
# (0.9107755102040817, 0.9092698412698412, 0.9108888888888889)

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - All the accuracy level is within a range of 0.909 to 0.910, the difference is very nominal.
# - There is so symptom of overfitting still now.
# - We will further analyse the same after prunning to reach the final conclusion.

# %%
prun_clf = DecisionTreeClassifier(random_state=159, criterion='entropy', max_depth=10, min_samples_split=2)
path = prun_clf.cost_complexity_pruning_path(X_train_scaled, y_train)
ccp_alphas = path.ccp_alphas

clfs = [DecisionTreeClassifier(random_state=159, 
                               criterion='entropy', 
                               max_depth=10, 
                               min_samples_split=2, 
                               ccp_alpha=a).fit(X_train_scaled, y_train) for a in ccp_alphas]

# Evaluate and find the best alpha (excluding trivial root node)
val_scores = [clf.score(X_val_scaled, y_val) for clf in clfs[:-1]]
test_scores = [clf.score(X_test_scaled, y_test) for clf in clfs[:-1]]

# Visualize Accuracy vs Alpha
plt.figure(figsize=(8, 5))
plt.plot(ccp_alphas[:-1], [c.score(X_train_scaled, y_train) for c in clfs[:-1]], label="Train")
plt.plot(ccp_alphas[:-1], val_scores, label="Validation")
plt.plot(ccp_alphas[:-1], test_scores, label="Test")
plt.xlabel("Alpha"), plt.ylabel("Accuracy"), plt.legend()
plt.show()

# %% [markdown]
# ---
# <a name = Section2></a>
# #### Insights:
#
# - At very small alpha values (0.00-0.02), accuracy drops sharply from 91% to 87%.
# - This shows that initial pruning removes redundant complexity from the tree without
#   much accuracy loss. The train, validation, and test curves quickly converge,
#   indicating minimal overfitting.
# - The three curves stay very close together throughout, meaning the unpruned tree
#   (max_depth=10) wasn't severely overfitting.
# - The train curve barely leads validation/test at small alphas, showing good generalization.
# - At alpha values ≈ 0.02-0.05, there's a notable plateau where all three curves (train,
#   validation, test) converge around 85% accuracy. This is the optimal range where the
#   model balances simplicity and predictive power.
# - Beyond α = 0.05, accuracy continuously declines as more nodes are removed. This
#   indicates loss of important decision patterns needed for prediction.
#
# #### Conclusion:
#
# Pruning with α=0.029 creates a simpler, more interpretable tree while maintaining strong
# predictive accuracy with excellent generalization to unseen data.

# %%
dtree_model = DecisionTreeClassifier(random_state=159, 
                                     criterion='entropy', 
                                     max_depth=10, 
                                     min_samples_split=2, 
                                     ccp_alpha=0.029)
dtree_model.fit(X_train_scaled, y_train)
dtree_model
# Out:
# DecisionTreeClassifier(ccp_alpha=0.029, criterion='entropy', max_depth=10,
#                        random_state=159)

# %%
y_val_pred = dtree_model.predict(X_val_scaled)
accuracy = accuracy_score(y_val, y_val_pred)
print(f"Validation Accuracy: {accuracy:.4f}")


print("Validation Classification Report for Decision Tree:")
print(classification_report(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.8638
# Validation Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.83      0.95      0.88     52132
#            1       0.92      0.76      0.83     42368
#
#     accuracy                           0.86     94500
#    macro avg       0.88      0.85      0.86     94500
# weighted avg       0.87      0.86      0.86     94500

# %%
y_test_pred = dtree_model.predict(X_test_scaled)
accuracy = accuracy_score(y_test, y_test_pred)
print(f"Test Accuracy: {accuracy:.4f}")


print("Test Classification Report for Decision Tree:")
print(classification_report(y_test, y_test_pred))
# Out:
# Test Accuracy: 0.8631
# Test Classification Report for Decision Tree:
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.88     52132
#            1       0.92      0.76      0.83     42368
#
#     accuracy                           0.86     94500
#    macro avg       0.87      0.85      0.86     94500
# weighted avg       0.87      0.86      0.86     94500

# %%
clean_test_data.head()
# Out:
#        id  Age  Sex  Chest pain type        BP  Cholesterol  FBS over 120  \
# 0  630000   58    1                3 120.00000    288.00000             0
# 1  630001   55    0                2 120.00000    209.00000             0
# 2  630002   54    1                4 120.00000    268.00000             0
# 3  630003   44    0                3 112.00000    177.00000             0
# 4  630004   43    1                1 138.00000    267.00000             0
#
#    EKG results    Max HR  Exercise angina  ST depression  Slope of ST  \
# 0            2 145.00000                1        0.80000            2
# 1            0 172.00000                0        0.00000            1
# 2            0 150.00000                1        0.00000            2
# 3            0 168.00000                0        0.90000            1
# 4            0 163.00000                0        1.80000            2
#
#    Number of vessels fluro  Thallium  Expected_Max_HR  HR_Reserve  \
# ...

# %%
X_final_test_scaled = scaler.transform(clean_test_data.drop(columns=['id','BP_Category']))

y_final_test_pred = dtree_model.predict(X_final_test_scaled)
final_predictions = pd.DataFrame({
    'id': clean_test_data['id'],
    'Heart_Disease_Target': y_final_test_pred
})
final_predictions['Heart Disease'] = final_predictions['Heart_Disease_Target'].map({1: 'Presence', 0: 'Absence'})
final_predictions = final_predictions[['id', 'Heart Disease']]
final_predictions.head()
# Out:
#        id Heart Disease
# 0  630000       Absence
# 1  630001       Absence
# 2  630002      Presence
# 3  630003       Absence
# 4  630004      Presence

# %%
final_predictions.to_csv('data\\output\\heart_disease\\heart_disease_predictions.csv', index=False)

# %%
with open('data\\output\\heart_disease\\decision_tree_model.pkl', 'wb') as f:
    pickle.dump(dtree_model, f)
