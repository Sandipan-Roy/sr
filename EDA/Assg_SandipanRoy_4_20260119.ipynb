# %% [markdown]
# <div style="display:flex;align-items:center;justify-content:center;flex-direction:column;padding:18px 0;">
# <h1 style="font-family: 'Segoe UI', Roboto, Arial; font-size:48px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">
# EXPLORATORY DATA ANALYSIS(EDA) ASSIGNMENT
# </h1>
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">A concise workbook covering advanced skills in using NumPy, Pandas, Matplotlib and Seaborn, uncovering insights, patterns, and relationships within the data.<br /><br />
# Exploratory Data Analysis (EDA) in Data Science is the critical initial process of analyzing, cleaning, and visualizing datasets to uncover underlying patterns, detect anomalies, test assumptions, and check data quality before building predictive models. It acts as a foundational step to understand data structure and relationships using statistical summaries and graphs</p>
# </div>
#
# ---
#
# <div style="display:flex;gap:12px;flex-wrap:wrap;align-items:center;">
# <span style="background:#eef2ff;color:#3730a3;padding:6px 10px;border-radius:8px;font-weight:600;">📘 Basics</span>
# <span style="background:#ecfdf5;color:#065f46;padding:6px 10px;border-radius:8px;font-weight:600;">⚙️ Examples</span>
# <span style="background:#fff7ed;color:#92400e;padding:6px 10px;border-radius:8px;font-weight:600;">🔁 Exercises</span>
# </div>
#
#
# <details><summary><strong>Notebook info</strong></summary>
#
# - **Author:** Sandipan Roy
# - **Assignment Date:** 2026-01-19
# - **Assignment Given By:** Karkavel Raja
# - **Sections:** Importing Libraries · Data Loading · Data Preprocessing & Transformation Operations · Exploratory Data Analysis (EDA) · Fine-tuning and Optimization
#
# </details>
#
# ---

# %% [markdown]
# <div style="display:flex;align-items:center;justify-content:center;flex-direction:column;padding:18px 0;">
# <h2 style="font-family: 'Segoe UI', Roboto, Arial; font-size:38px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">Problem Statement:</h2>
#
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">The objective of this assignment is to perform an in-depth Exploratory Data Analysis on the Titanic dataset, uncovering insights, patterns, and relationships within the data. Through this analysis, students will gain familiarity with various EDA techniques and derive meaningful conclusions from the dataset.</p>
# </div>
#
# ---

# %% [markdown]
# <div style="display:flex;align-items:center;justify-content:center;flex-direction:column;padding:18px 0;">
# <h2 style="font-family: 'Segoe UI', Roboto, Arial; font-size:38px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">Dataset for the Assignment:</h2>
#
# ---
#
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
#
#
# [Titanic Dataset | Kaggle](https://www.kaggle.com/competitions/titanic/data)
#
#
# </p>
# </div>
#
# ---

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">1. Data Loading and Preprocessing:</h3>
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Import necessary libraries: pandas, matplotlib, seaborn, etc.</u></li>
# </ul>
# </p>

# %%
# Importing warning to disable runtime warnings
import warnings
# Warnings will appear only once
warnings.filterwarnings("ignore")

#=================================================================================

# Importing Numpy Library and aliasing it's name as np
import numpy as np
# Importing Pandas Library and aliasing it's name as pd
import pandas as pd
# Importing the Pyplot Interface from within the Matplotlib Library and aliasing it as plt
import matplotlib.pyplot as plt
# The above line of code can also be written as-
#    from matplotlib import pyplot as plt

# Importing Seaborn Library and aliasing it's name as sns
import seaborn as sns

#=================================================================================

# Unfolding hidden features if the cardinality is high
pd.set_option('display.max_columns', None)
# Unfolding the max feature width for better clearity
pd.set_option('display.max_colwidth', None)
# Unfolding hidden data points if the cardinality is high
pd.set_option('display.max_rows', None)
# Removing restriction over chained assignments operations
pd.set_option('mode.chained_assignment', None)
# To suppress scientific notation over exponential values
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# %matplotlib inline

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Load the Titanic dataset and handle missing values or inconsistencies.</u></li>
# </ul>
# </p>

# %%
url = "https://raw.githubusercontent.com/Sandipan-Roy/sr/refs/heads/Dev/EDA/data/raw/train.csv"
titanicDf = pd.read_csv(url)
print(f"Data Shape: {titanicDf.shape}")
titanicDf.info()
# Out:
# Data Shape: (891, 12)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ---
# <a name = Section4></a>
# ### Data Acquisition Observations
# ---
#
#
# The dataset consists of the information about people boarding the famous RMS Titanic.
#
#
# | Records | Features | Dataset Size |
# | :-- | :-- | :-- |
# | 891 | 12 | 83.7 KB |
#
#
# | ID | Feature Name | Description of the feature | Data Type |
# | :-- | :--| :--| :--|
# |01| **PassengerId**   | Identity of the passenger                                    | int64 |
# |02| **Survived**      | Whether the passenger survived or not                 | int64 |
# |03| **Pclass**        | Class of the ticket holder                            | int64 |
# |04| **Name**          | Name of the passenger                                 | object |
# |05| **Sex**           | Sex of the passenger                                  | object |
# |06| **Age**           | Age of the passenger                                  | float64 |
# |07| **SibSp**     | Siblings and/or spouse travelling with passenger | int64 |
# |08| **Parch**     | Parents and/or children travelling with passenger| int64 |
# |09| **Ticket**        | Ticket number                                         | object |
# |10| **Fare**          | Price of the ticket                                   | float64 |
# |11| **Cabin**         | Cabin number                                          | object |
# |12| **Embarked**     | Port of Embarkation                                   | object |
#
# ---
#
# - Data types of all the features look appropriate.
# - There are missing values in features Age, Cabin and Embarked.
# - Age and Cabin have a significant amount of missing values which requires further investigation.

# %%
titanicDf.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex      Age  \
# 0                              Braund, Mr. Owen Harris    male 22.00000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.00000
# 2                               Heikkinen, Miss. Laina  female 26.00000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00000
# 4                             Allen, Mr. William Henry    male 35.00000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked
# 0      1      0         A/5 21171  7.25000   NaN        S
# 1      1      0          PC 17599 71.28330   C85        C
# 2      0      0  STON/O2. 3101282  7.92500   NaN        S
# 3      1      0            113803 53.10000  C123        S
# ...

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Perform data cleaning and preprocessing for analysis.</u></li>
# </ul>
# </p>

# %%
df_clean = titanicDf.copy()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df_clean.duplicated().sum()
# Out:
# np.int64(0)

# %%
total_datapoints, total_features = df_clean.shape
total_datapoints, total_features
# Out:
# (891, 12)

# %% [markdown]
# From the execution of the above code, we can conclude that there are no duplicate data.

# %% [markdown]
# ---
# <a name = Section4></a>
# ### Hypothesis on Cabin w.r.t. Pclass
# ---
#
# - Cabin Number ("Cabin") was only provided to those passengers who were travelling in Pclass = 1.

# %%
df_clean.groupby(by = ["Pclass"])["Cabin"].unique()
# Out:
# Pclass
# 1    [C85, C123, E46, C103, A6, C23 C25 C27, nan, B78, D33, B30, C52, B28, C83, E31, A5, D10 D12, D26, C110, B58 B60, D47, B86, C2, E33, B19, A7, C49, A32, B4, B80, A31, D36, D15, C93, C78, D35, C87, B77, E67, B94, C125, C99, C118, D7, A19, B49, C22 C26, C106, C65, E36, C54, B57 B59 B63 B66, C7, E34, C32, B18, C124, C91, E40, T, C128, D37, B35, E50, C82, B96 B98, E44, A34, C104, C111, C92, E38, D21, E12, E63, A14, B37, C30, D20, B79, E25, D46, B73, C95, B38, B39, B22, C86, C70, A16, C101, C68, A10, E68, B41, A20, D19, D50, D9, A23, B50, ...]
# ...

# %%
df_clean.groupby(by = ["Pclass"])["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
print(f"Pclass = 1 Pclass Data Distribution: {216*100/891}%")
print(f"Pclass = 2 Pclass Data Distribution: {184*100/891}%")
print(f"Pclass = 3 Pclass Data Distribution: {491*100/891}%")
# Out:
# Pclass = 1 Pclass Data Distribution: 24.242424242424242%
# Pclass = 2 Pclass Data Distribution: 20.650953984287316%
# Pclass = 3 Pclass Data Distribution: 55.10662177328844%

# %%
df_clean.groupby(by = ["Pclass"])["Cabin"].count()
# Out:
# Pclass
# 1    176
# 2     16
# 3     12
# Name: Cabin, dtype: int64

# %%
print(f"Pclass = 1 Cabin Data Availability: {176*100/216}%")
print(f"Pclass = 2 Cabin Data Availability: {16*100/184}%")
print(f"Pclass = 3 Cabin Data Availability: {12*100/491}%")
# Out:
# Pclass = 1 Cabin Data Availability: 81.48148148148148%
# Pclass = 2 Cabin Data Availability: 8.695652173913043%
# Pclass = 3 Cabin Data Availability: 2.443991853360489%

# %% [markdown]
# ---
# <a name = Section4></a>
# ### Conclussion on our assumption on Cabin
# ---
#
# - We can see that, Cabin number is available to passengers irrespective of the Pclass value
#
# | Sl No. | Pclass | Pclass Size | Cabin Number Availability Count |
# | :-- | :-- | :-- | :-- |
# | 1 | 1 | 216 | 176 |
# | 2 | 2 | 184 | 16 |
# | 3 | 3 | 491 | 12 |
#
# - Most of the data w.r.t. Cabin is available only for the Pclass 1 which is approx 81% and for the remaining classes it's below 10% individually.
#
# [Note:- the above percentage data is w.r.t. each categorical value count not overall data.]
#
# - Overall, distribution of Pclass
# | Pclass | Pclass Size | Pclass Distribution % |
# | :-- | :-- | :-- |
# | 1 | 216 | 24.24 |
# | 2 | 184 | 20.65 |
# | 3 | 491 | 55.11 |
#
# - From the above two tables, it looks like that it's a data loss scenario due to improper data entry.
#
# So our assumption on the feature Cabin- that Cabin number was only provided to passengers travelling in the class 1 was wrong, hence we are nullyfying it.

# %% [markdown]
# ---
# <a name = Section4></a>
# ### Analysis on the missing data of the feature 'Embarked'
# ---
#
# - For 2 records we don't have any entry for the feature Embarked.

# %%
df_clean[df_clean["Embarked"].isna()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 61   female 38.00000      0      0  113572 80.00000   B28      NaN
# 829  female 62.00000      0      0  113572 80.00000   B28      NaN

# %% [markdown]
# ---
#
#
# *   Is there any co-passenger Cabin = 'B28' or Ticket = '113572' apart from them in the same Cabin and Ticket No?
# ---

# %%
df_clean.query("Cabin == 'B28' or Ticket == '113572' ")
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex      Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 61   female 38.00000      0      0  113572 80.00000   B28      NaN
# 829  female 62.00000      0      0  113572 80.00000   B28      NaN

# %% [markdown]
# ---
#
# Ans: No, there is no record of any other co-passenger Cabin = 'B28' or Ticket = '113572' apart with the same Cabin and Ticket No.
#
# ---

# %% [markdown]
# ---
#
#
# *   Is there any co-passenger where Cabin = 'B28' or Ticket = '113572' and having the same title (though SibSp and Parch value is 0)?
#
# ---

# %%
df_clean.query("Cabin == 'B28' or Ticket == '113572' or Name.str.contains('George Nelson') or Name.str.contains('Stone') or Name.str.contains('Icard')")
# Out:
#      PassengerId  Survived  Pclass  \
# 61            62         1       1
# 319          320         1       1
# 829          830         1       1
#
#                                                          Name     Sex  \
# 61                                        Icard, Miss. Amelie  female
# 319  Spedden, Mrs. Frederic Oakley (Margaretta Corning Stone)  female
# 829                 Stone, Mrs. George Nelson (Martha Evelyn)  female
#
#          Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 61  38.00000      0      0  113572  80.00000   B28      NaN
# 319 40.00000      1      1   16966 134.50000   E34        C
# 829 62.00000      0      0  113572  80.00000   B28      NaN

# %% [markdown]
# ---
#
# Ans: Yes we can find only one passenger which satisfies our criteria. However, if we consider the feature Fare we can see that their is a considerable amount of difference in their fare. So, it's likelyhood is very less.
#
# ---

# %% [markdown]
# ---
#
# *   The feature- 'Fare' is continuous in nature
# *   Probability of a continuous data is zero, however we can find the probability of a continuous variable over a given range.
# *   Since our earlier approach shown us that w.r.t. 'Ticket', 'Cabin' or subset of 'Name' is not enough to find the 'Embarked' info for the missing data.
# *   Hence, we are creating a mask where we will mention the 'Fare' over a range,'Embarked' with no missing data and 'Survived' equals to True or 1.
# *   The objective is to get a close approximation by using the central tendency and fill the missing data w.r.t. the feature 'Fare' and 'Survived'

# %%
embarkment_mask = df_clean.query("Fare <= 80.00000 & Fare >=70.00000 & ~Embarked.isna() & Survived == 1")
embarkment_mask.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 1 to 765
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  17 non-null     int64
#  1   Survived     17 non-null     int64
#  2   Pclass       17 non-null     int64
#  3   Name         17 non-null     object
#  4   Sex          17 non-null     object
#  5   Age          16 non-null     float64
#  6   SibSp        17 non-null     int64
#  7   Parch        17 non-null     int64
#  8   Ticket       17 non-null     object
#  9   Fare         17 non-null     float64
#  10  Cabin        15 non-null     object
#  11  Embarked     17 non-null     object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 1.7+ KB

# %%
embarkment_mask
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 52            53         1       1
# 218          219         1       1
# 256          257         1       1
# 275          276         1       1
# 290          291         1       1
# 366          367         1       1
# 496          497         1       1
# 540          541         1       1
# 558          559         1       1
# 585          586         1       1
# 587          588         1       1
# 591          592         1       1
# 627          628         1       1
# 645          646         1       1
# 681          682         1       1
# 765          766         1       1
#
#                                                     Name     Sex      Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.00000
# 52              Harper, Mrs. Henry Sleeper (Myna Haxtun)  female 49.00000
# 218                                Bazzani, Miss. Albina  female 32.00000
# ...

# %%
embarkment_mask["Embarked"].mode()
# Out:
# 0    C
# Name: Embarked, dtype: object

# %%
df_clean["Embarked"].fillna(value=embarkment_mask["Embarked"].mode()[0], inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">2. Basic Analysis:</h3>
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Compute basic statistics, visualize distributions, and generate initial insights.</u></li>
# </ul>
# </p>

# %%
df_clean[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].describe()
# Out:
#        Survived    Pclass       Age     SibSp     Parch      Fare
# count 891.00000 891.00000 714.00000 891.00000 891.00000 891.00000
# mean    0.38384   2.30864  29.69912   0.52301   0.38159  32.20421
# std     0.48659   0.83607  14.52650   1.10274   0.80606  49.69343
# min     0.00000   1.00000   0.42000   0.00000   0.00000   0.00000
# 25%     0.00000   2.00000  20.12500   0.00000   0.00000   7.91040
# 50%     0.00000   3.00000  28.00000   0.00000   0.00000  14.45420
# 75%     1.00000   3.00000  38.00000   1.00000   0.00000  31.00000
# max     1.00000   3.00000  80.00000   8.00000   6.00000 512.32920

# %% [markdown]
# ---
# <a name = Section2></a>
# ### Statistical Analysis of the Data
# ---
#
#
# > **Survived**:
# - More than 50% did not survive the accident (mean= 0.38384).
#
# > **Pclass**:
# - There are a lot **more 3rd class** passengers than **1st and 2nd class**.
# - We can also see that there are **more 2nd class** passengers **than 1st class** passengers.
#
# > **SibSp**:
# - More than **50%** of passengers are **not travelling** with their **siblings** or a **spouse**.
# - There are **some** passengers who are travelling with as **maximum** as **8 siblings and spouse**.
#
# > **Parch**:
# - More than **75%** passengers are not travelling with a **parent** or **children**
# - But there are some passengers who have a **maximum** number of **6 children** and/or **parents** with them on the ship.
# - We observe that a vast majority of passengers **are not travelling** with their family members.
#
# > **Age**:
# - The **average age** of passengers is around **29 years** while the **minimum** and **maximum** ages are **0.4 years** and **80 years** respectively.
# - There is some **missing** data in the **Age** feature.
#
# > **Fare**:
# - The **average price** of ticket seems to be **£32.2**. **Minimum** price of the ticket is recorded as **£0** and **maximum** price recorded as high as **£512.32**.
# - More than **50%** of the passengers have paid atleast **£14**
# - More than **75%** passengers have paid atleast **£7** for their ticket whereas **less than 25%** have paid for **more than £31**.
# - We have to replace the minimum value in the **Fare** feature with a reasonable value.

# %%
df_clean["Survived"].value_counts()

fig = plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df_clean, x='Survived', palette='magma')

for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.title("Survival Count")
plt.xlabel("Survived (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ---
#
#
# *   Out of the entire passengers only 38.38% people was rescued successfuly after the accident, rest were not so much lucky.
# ---

# %%
fig = plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df_clean, x='Pclass', palette='magma')

for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xlabel("Passenger Class")
plt.ylabel("Count")
plt.title("Passenger Class Distribution")

plt.show()

# %% [markdown]
# ---
#
#
# *   Most of the passengers(55.11%) was travelling with tickets of Class 3
# *   Almost 24.24% of passengers was travelling with tickets of Class 1
# *   Remaining 20.65% of passengers has boarded in Class 2
# ---

# %%
fig = plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df_clean, x='Sex', palette='magma')

for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xlabel("Gender")
plt.ylabel("Count")
plt.title("Gender Distribution")

plt.show()

# %% [markdown]
# ---
#
#
# *   Almost 65% passengers were Male
# *   Approx 35% passengers were Female
# ---

# %%
fig = plt.figure(figsize=(6, 4))
ax = sns.countplot(data=df_clean, x='Embarked', palette='magma')

for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))

plt.xlabel("Emberked")
plt.ylabel("Count")
plt.title("Distribution of Passengers w.r.t. port of Boarding")

plt.show()

# %% [markdown]
# ---
#
#
# *   Approx 72% passengers have boarded from the port S
# *   Approx 19% passengers have boarded from the port C
# *   Approx 9% passengers have boarded from the port Q
# ---

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">3. Intermediate Analysis:</h3>
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Explore correlations, patterns, and relationships among features.</u></li>
# </ul>
# </p>

# %%
df_dummies = pd.get_dummies(df_clean['Sex'], drop_first=True, dtype=np.uint8, prefix = 'Is')
df_clean = pd.concat([df_clean, df_dummies], axis=1)
df_clean.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex      Age  \
# 0                              Braund, Mr. Owen Harris    male 22.00000
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female 38.00000
# 2                               Heikkinen, Miss. Laina  female 26.00000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00000
# 4                             Allen, Mr. William Henry    male 35.00000
#
#    SibSp  Parch            Ticket     Fare Cabin Embarked  Is_male
# 0      1      0         A/5 21171  7.25000   NaN        S        1
# 1      1      0          PC 17599 71.28330   C85        C        0
# 2      0      0  STON/O2. 3101282  7.92500   NaN        S        0
# ...

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
#  12  Is_male      891 non-null    uint8
# dtypes: float64(2), int64(5), object(5), uint8(1)
# memory usage: 84.5+ KB

# %%
df_clean[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Is_male']].corr(numeric_only=True)
# Out:
#           Survived   Pclass      Age    SibSp    Parch     Fare  Is_male
# Survived   1.00000 -0.33848 -0.07722 -0.03532  0.08163  0.25731 -0.54335
# Pclass    -0.33848  1.00000 -0.36923  0.08308  0.01844 -0.54950  0.13190
# Age       -0.07722 -0.36923  1.00000 -0.30825 -0.18912  0.09607  0.09325
# SibSp     -0.03532  0.08308 -0.30825  1.00000  0.41484  0.15965 -0.11463
# Parch      0.08163  0.01844 -0.18912  0.41484  1.00000  0.21622 -0.24549
# Fare       0.25731 -0.54950  0.09607  0.15965  0.21622  1.00000 -0.18233
# Is_male   -0.54335  0.13190  0.09325 -0.11463 -0.24549 -0.18233  1.00000

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Create visualizations to support findings and explore data interactions.</u></li>
# </ul>
# </p>

# %%
fig = plt.figure(figsize=(6, 4))
ax = pd.crosstab(df_clean["Sex"], df_clean["Survived"]).plot(kind="bar")

for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))


plt.title("Survival by Gender")
plt.xlabel("Sex")
plt.ylabel("Count")
plt.show()

# %%
df_clean["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df_clean.groupby(["Sex", "Survived"])["Survived"].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
print(f"Survival rate for Female: {(233*100/314):.2f}")
print(f"Survival rate for Male: {(109*100/577):.2f}")
# Out:
# Survival rate for Female: 74.20
# Survival rate for Male: 18.89

# %% [markdown]
# ---
#
#
# *   Female are having higher survival rate (74.20%) than male(18.89%).
# *   May be at the time of rescue operations Female was given higher priority.
#
# ---

# %%
fig = plt.figure(figsize=(6, 4))
ax = pd.crosstab(df_clean["Embarked"], df_clean["Survived"]).plot(kind="bar")

for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))


plt.title("Survival by port of Embarkment")
plt.xlabel("Embarkment")
plt.ylabel("Count")
plt.show()

# %%
df_clean["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    170
# Q     77
# Name: count, dtype: int64

# %%
df_clean.groupby(["Embarked", "Survived"])["Survived"].count()
# Out:
# Embarked  Survived
# C         0            75
#           1            95
# Q         0            47
#           1            30
# S         0           427
#           1           217
# Name: Survived, dtype: int64

# %%
print(f"Percentage of people survived on Embarkment from 'S': {(217*100/644):.2f}")
print(f"Percentage of people survived on Embarkment from 'Q': {(30*100/77):.2f}")
print(f"Percentage of people survived on Embarkment from 'C': {(95*100/170):.2f}")
# Out:
# Percentage of people survived on Embarkment from 'S': 33.70
# Percentage of people survived on Embarkment from 'Q': 38.96
# Percentage of people survived on Embarkment from 'C': 55.88

# %% [markdown]
# ---
#
#
# *   Survival Rate w.r.t. port of Embarkment can be represented as :
# C (55.88%) > Q (38.96%) > S (33.70%)
# ---

# %%
# Creating a new feature FamilySize from Sibsp and Parch
df_clean["FamilySize"] = df_clean["SibSp"] + df_clean["Parch"] + 1
df_clean.describe()
# Out:
#        PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# count    891.00000 891.00000 891.00000 714.00000 891.00000 891.00000
# mean     446.00000   0.38384   2.30864  29.69912   0.52301   0.38159
# std      257.35384   0.48659   0.83607  14.52650   1.10274   0.80606
# min        1.00000   0.00000   1.00000   0.42000   0.00000   0.00000
# 25%      223.50000   0.00000   2.00000  20.12500   0.00000   0.00000
# 50%      446.00000   0.00000   3.00000  28.00000   0.00000   0.00000
# 75%      668.50000   1.00000   3.00000  38.00000   1.00000   0.00000
# max      891.00000   1.00000   3.00000  80.00000   8.00000   6.00000
#
#            Fare   Is_male  FamilySize
# count 891.00000 891.00000   891.00000
# mean   32.20421   0.64759     1.90460
# std    49.69343   0.47799     1.61346
# min     0.00000   0.00000     1.00000
# 25%     7.91040   0.00000     1.00000
# 50%    14.45420   1.00000     1.00000
# 75%    31.00000   1.00000     2.00000
# ...

# %%
sns.histplot(data=df_clean, x="FamilySize", kde=True, bins=11)
plt.title("Histogram with KDE for Family Size")
plt.show()

# %% [markdown]
# ---
#
#
# *   More than 50% people travelled alone
# *   The entire data w.r.t. Family Size is right-skewed with the extreme value equal to 11.
# ---

# %%
plt.figure()
pd.crosstab(df_clean["FamilySize"], df_clean["Survived"]).plot(kind="bar")
plt.title("Survival by Family Size")
plt.xlabel("Family Size")
plt.ylabel("Count")
plt.show()

# %%
df_clean["FamilySize"].value_counts()
# Out:
# FamilySize
# 1     537
# 2     161
# 3     102
# 4      29
# 6      22
# 5      15
# 7      12
# 11      7
# 8       6
# Name: count, dtype: int64

# %%
df_clean.groupby(["FamilySize", "Survived"])["Survived"].count()
# Out:
# FamilySize  Survived
# 1           0           374
#             1           163
# 2           0            72
#             1            89
# 3           0            43
#             1            59
# 4           0             8
#             1            21
# 5           0            12
#             1             3
# 6           0            19
#             1             3
# 7           0             8
#             1             4
# 8           0             6
# 11          0             7
# Name: Survived, dtype: int64

# %% [markdown]
# ---
#
# *   It looks like with increase in family size, rate of survival decreases; but need further in depth analysis to conclude this hypothesis.
# ---

# %%
fig = plt.figure(figsize=(15, 7))

# Plotting a pointplot of FamilySize vs survived.
sns.pointplot(x='FamilySize', y='Survived', data=df_clean, color='red')

# Adding some cosmetics - ticks, labels, title, and grid to the pointplot.
plt.title(label='Factorplot for FamilySize vs Survived', size=16)
plt.xticks(size=12)
plt.yticks(size=12)
plt.xlabel(xlabel='Family Size', size=14)
plt.ylabel(ylabel='Survived', size=14)
plt.grid(visible=True)

# Display the figure.
plt.show()

# %% [markdown]
# ---
#
# *   As family size increases survivability decreases
# *   This indicates, all the family members couldn't be saved
# *   Also, we can see a lot of passengers those who was aboard alone has also died.
# *   Probability of survival for family size upto 4 is higher compared to it's tail end or when the family size is more than 4 then survival chances decreases.
#
# ---

# %%
df_clean["Title"] = df_clean["Name"].str.split(",").str[1].str.split(".").str[0].str.strip()
df_clean["Title"].value_counts()
# Out:
# Title
# Mr              517
# Miss            182
# Mrs             125
# Master           40
# Dr                7
# Rev               6
# Col               2
# Mlle              2
# Major             2
# Ms                1
# Mme               1
# Don               1
# Lady              1
# Sir               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Name: count, dtype: int64

# %%
df_clean['Title'].replace(to_replace=['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don'],
                      value=['Miss', 'Miss', 'Miss', 'Other', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr'],
                      inplace=True)
df_clean["Title"].value_counts()
# Out:
# Title
# Mr              522
# Miss            186
# Mrs             126
# Master           40
# Other            16
# the Countess      1
# Name: count, dtype: int64

# %%
pd.crosstab(index=df_clean['Sex'], columns=df_clean['Title'])
# Out:
# Title   Master  Miss   Mr  Mrs  Other  the Countess
# Sex
# female       0   186    0  126      1             1
# male        40     0  522    0     15             0

# %% [markdown]
# ---
#
#
# - We can see that "gender" and "titles" matches with each other ("Mr" and "Master" for "males", "Miss" and "Mrs" for "females")
#
# - We can use this feature to check if a "title" of a person played an important role in their "survival".
#
# ---

# %%
sns.catplot(x="Age", y="Title", data=df_clean, size=7, aspect=3)

plt.xticks(size=12)
plt.yticks(size=12)
plt.xlabel(xlabel='Age', size=14)
plt.ylabel(ylabel='Title', size=14)
plt.title(label='Age concerning Title of Passengers', size=16)
plt.grid(visible=True)

plt.show()

# %%
df_clean.groupby(["Title"])["Age"].agg(["min","max"])
# Out:
#                   min      max
# Title
# Master        0.42000 12.00000
# Miss          0.75000 63.00000
# Mr           11.00000 80.00000
# Mrs          14.00000 63.00000
# Other        23.00000 60.00000
# the Countess 33.00000 33.00000

# %% [markdown]
# ---
#
#
# *   "Title" doesn't matches with our conventional "Age" group range standard consideration
# *   "Title" - 'Mrs' can be debatable based on "Female" gender
# *   "Mr" age as low as 11 to as high as 80
#
# ---

# %%
df_clean[df_clean["Age"].isna()]["Title"].value_counts()
# Out:
# Title
# Mr        119
# Miss       36
# Mrs        17
# Master      4
# Other       1
# Name: count, dtype: int64

# %%
df_clean[~df_clean["Age"].isna()].groupby("Title")["Age"].median()
# Out:
# Title
# Master          3.50000
# Miss           21.50000
# Mr             30.00000
# Mrs            35.00000
# Other          49.00000
# the Countess   33.00000
# Name: Age, dtype: float64

# %%
df_clean["Age"].fillna(value=df_clean.groupby("Title")["Age"].transform("median"), inplace=True)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
#  12  Is_male      891 non-null    uint8
#  13  FamilySize   891 non-null    int64
#  14  Title        891 non-null    object
#  15  Deck         891 non-null    object
#  16  IsAlone      891 non-null    int64
# dtypes: float64(2), int64(7), object(7), uint8(1)
# memory usage: 112.4+ KB

# %% [markdown]
# ---
# Does the Title played a vital role at the time of rescue operation?
# ---

# %%
fig = plt.figure(figsize=[15, 7])

# Creating countplot of title vs survive
ax = sns.countplot(y='Title', hue='Survived', data=df_clean, palette='hls')

# Adding percentages to the bars
for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_width() / total_datapoints)
    x = p.get_x() + p.get_width()
    y = p.get_y() + p.get_height() / 2
    ax.annotate(percentage, (x, y))

# Adding some cosmetics
plt.yticks(size=12)
plt.xticks(size=12)
plt.xlabel(xlabel="Count", size=14)
plt.ylabel(ylabel='Title', size=14)
plt.title(label="Count plot for Title concerning with survival", size=16)
plt.legend(labels=["Didn't Survive", "Survive"])
plt.grid(visible=True)

# Display the figure
plt.show()

# %% [markdown]
# ---
#
#
#
# *   Title's like- Miss and Mrs have higher survival rates compared to other Titles
# *   Passengers with Title Mr. died the most
# *   Passengers with Title Master is also having medium label of survival rate
# *   For Other's we can't conclude whether they given any priority at the time of rescue or not.
#
# ---

# %%
(df_clean["Cabin"].str.len()).max()
# Out:
# 15.0

# %%
(df_clean["Cabin"].str.len()).median()
# Out:
# 3.0

# %%
(df_clean[~df_clean["Cabin"].isna()]["Cabin"].str.len()).min()
# Out:
# 1

# %%
df_clean[df_clean["Cabin"].str.len() == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 292          293         0       2
# 327          328         1       2
# 339          340         0       1
# 473          474         1       2
#
#                                              Name     Sex      Age  SibSp  \
# 292                        Levy, Mr. Rene Jacques    male 36.00000      0
# 327                       Ball, Mrs. (Ada E Hall)  female 36.00000      0
# 339                  Blackwell, Mr. Stephen Weart    male 45.00000      0
# 473  Jerwan, Mrs. Amin S (Marie Marthe Thuillard)  female 23.00000      0
#
#      Parch           Ticket     Fare Cabin Embarked  Is_male  FamilySize Title
# 292      0    SC/Paris 2163 12.87500     D        C        1           1    Mr
# 327      0            28551 13.00000     D        S        0           1   Mrs
# 339      0           113784 35.50000     T        S        1           1    Mr
# 473      0  SC/AH Basle 541 13.79170     D        C        0           1   Mrs

# %%
(df_clean[~df_clean["Cabin"].isna()]["Cabin"].str.len()).value_counts()
# Out:
# Cabin
# 3     128
# 4      24
# 2      24
# 7      12
# 11      6
# 5       4
# 1       4
# 15      2
# Name: count, dtype: int64

# %%
unique_cabin_len = np.sort((df_clean[~df_clean["Cabin"].isna()]["Cabin"].str.len()).unique())

for i in unique_cabin_len:
  print(f"Cabin Number Length: {i}\n")
  print("-"*40)
  print(df_clean[df_clean["Cabin"].str.len() == i].head(2))
  print("="*40)
# Out:
# Cabin Number Length: 1
#
# ----------------------------------------
#      PassengerId  Survived  Pclass                     Name     Sex      Age  \
# 292          293         0       2   Levy, Mr. Rene Jacques    male 36.00000
# 327          328         1       2  Ball, Mrs. (Ada E Hall)  female 36.00000
#
#      SibSp  Parch         Ticket     Fare Cabin Embarked  Is_male  FamilySize  \
# 292      0      0  SC/Paris 2163 12.87500     D        C        1           1
# 327      0      0          28551 13.00000     D        S        0           1
#
#     Title
# 292    Mr
# 327   Mrs
# ...
# Cabin Number Length: 2
#
# ----------------------------------------
#     PassengerId  Survived  Pclass                             Name     Sex  \
# 10           11         1       3  Sandstrom, Miss. Marguerite Rut  female
# 23           24         1       1     Sloper, Mr. William Thompson    male
#
#         Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Is_male  \
# ...

# %%
df_clean["Deck"] = df_clean["Cabin"].str[0]  + df_clean["Pclass"].astype("str")  + df_clean["Embarked"].astype("str")
df_clean["Deck"].fillna(value="Unknown" + df_clean["Pclass"].astype("str") + df_clean["Embarked"].astype("str"), inplace=True)

df_clean["Deck"].value_counts()
# Out:
# Deck
# Unknown3S    343
# Unknown2S    151
# Unknown3Q     71
# Unknown3C     65
# C1S           36
# B1C           24
# B1S           23
# C1C           21
# Unknown1S     21
# E1S           20
# Unknown1C     19
# D1S           18
# Unknown2C     15
# D1C           11
# A1S            8
# F2S            8
# A1C            7
# E1C            5
# G3S            4
# E3S            3
# E2S            3
# F3S            3
# D2S            2
# Unknown2Q      2
# D2C            2
# C1Q            2
# F3C            1
# E2Q            1
# T1S            1
# F3Q            1
# Name: count, dtype: int64

# %%
plt.figure()
pd.crosstab(df_clean["Deck"], df_clean["Survived"]).plot(kind="bar")
plt.title("Survival by Deck")
plt.xlabel("Deck")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">4. Advanced Analysis:</h3>
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Utilize advanced visualization techniques and multivariate analysis to uncover deeper insights.</u></li>
# </ul>
# </p>

# %%
df_clean.corr(numeric_only=True)
# Out:
#              PassengerId  Survived   Pclass      Age    SibSp    Parch  \
# PassengerId      1.00000  -0.00501 -0.03514  0.03685 -0.05753 -0.00165
# Survived        -0.00501   1.00000 -0.33848 -0.07722 -0.03532  0.08163
# Pclass          -0.03514  -0.33848  1.00000 -0.36923  0.08308  0.01844
# Age              0.03685  -0.07722 -0.36923  1.00000 -0.30825 -0.18912
# SibSp           -0.05753  -0.03532  0.08308 -0.30825  1.00000  0.41484
# Parch           -0.00165   0.08163  0.01844 -0.18912  0.41484  1.00000
# Fare             0.01266   0.25731 -0.54950  0.09607  0.15965  0.21622
# Is_male          0.04294  -0.54335  0.13190  0.09325 -0.11463 -0.24549
# FamilySize      -0.04014   0.01664  0.06600 -0.30191  0.89071  0.78311
#
#                 Fare  Is_male  FamilySize
# PassengerId  0.01266  0.04294    -0.04014
# Survived     0.25731 -0.54335     0.01664
# Pclass      -0.54950  0.13190     0.06600
# Age          0.09607  0.09325    -0.30191
# SibSp        0.15965 -0.11463     0.89071
# ...

# %% [markdown]
# ---
#
# What is the survivability of passengers travelling alone?
# ---

# %%
df_clean["IsAlone"] = np.where(df_clean["FamilySize"] == 1, 1, 0)

plt.figure()
df_clean["IsAlone"].value_counts().plot(kind="bar")
plt.title("Is Alone Distribution")
plt.xlabel("IsAlone")
plt.ylabel("Count")
plt.show()

# %%
fig = plt.figure(figsize=(6, 4))
ax = pd.crosstab(df_clean["IsAlone"], df_clean["Survived"]).plot(kind="bar")

for p in ax.patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax.annotate(percentage, (x, y))


plt.title("Survival chance if alone")
plt.xlabel("Is Alone")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ---
#
#
#
# *   A large number of people was travelling alone
# *   Majority of people travelling alone didn't survive
# *   Passengers with atleast 1 Family member had almost equal chance of survival or death as compared to those who were alone
#
# ---

# %% [markdown]
# ---
#
# How does age played role in the survival of the passengers?
# ---

# %%
# Instantiate a figure of size of 20 x 7 inches with 2 subplots with 2:1
# width ratio
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(20, 7),
                       gridspec_kw={'width_ratios': [2, 1]})


# Creating a kdeplot of Age against survived in subplot 1
sns.kdeplot(x='Age', shade=True, hue='Survived', data=df_clean, ax=ax[0])

# Adding some cosmetics - labels, title, legend and grid to the kdeplot.
ax[0].set_title(label='Distribution of Age feature against Survival', size=16)
ax[0].set_ylabel(ylabel='Survived', size=14)
ax[0].set_xlabel(xlabel='Age', size=14)

ax[0].legend(labels=['Survived', "Didn't Survive"])
ax[0].grid(visible=True)

# Creating a boxplot of Age against survived in subplot 2
sns.boxplot(y='Age', x='Survived', data=df_clean, palette='muted', ax=ax[1])

# Adding some cosmetics - labels, title, and grid to the boxplot.
ax[1].set_title(label='Boxplot of Age feature against Survival', size=16)
ax[1].set_ylabel(ylabel='Age', size=14)
ax[1].set_xlabel(xlabel='Survived', size=14)
ax[1].set_xticklabels(labels=["Didn't Survive", "Survived"], fontsize=12)

ax[1].grid(visible=True)

# Setting a super title for the Age concerning survival plots
plt.suptitle(t='Influence of Age on Survival', size=18, y=1.0)

# Display the figures
plt.show()

# %% [markdown]
# ---
#
#
#
# - From the left graph, we can see that a lot of senior citizens (Age>60) died in the accident.
#
# - From both the graphs, we observe that the loss of children with Age less than 10 is not in significant amount.
#
# - From the right graph, we see that the eldest and the youngest person on the journey survived the shipwreck.
#
# - From both the graphs, we observe that majority of victims were from the 20-40 years age group.
#
# ---

# %% [markdown]
# ---
#
# What is the rate of survival for males and females w.r.t. boarding classes?
# ---

# %%
# Creating a crosstab between Survived, Sex and Pclass features
pd.crosstab(index=df_clean['Survived'], columns=[df_clean['Sex'], df_clean['Pclass']], margins=True).style.background_gradient(cmap='winter')
# Out:
# <style type="text/css">
# #T_d5ebc_row0_col0, #T_d5ebc_row0_col1, #T_d5ebc_row0_col2, #T_d5ebc_row1_col2, #T_d5ebc_row1_col3, #T_d5ebc_row1_col4, #T_d5ebc_row1_col5, #T_d5ebc_row1_col6 {
#   background-color: #0000ff;
#   color: #f1f1f1;
# }
# #T_d5ebc_row0_col3 {
#   background-color: #006aca;
#   color: #f1f1f1;
# }
# #T_d5ebc_row0_col4 {
#   background-color: #00d097;
#   color: #000000;
# }
# #T_d5ebc_row0_col5 {
#   background-color: #00d793;
#   color: #000000;
# }
# #T_d5ebc_row0_col6 {
#   background-color: #0060cf;
#   color: #f1f1f1;
# }
# #T_d5ebc_row1_col0 {
#   background-color: #00f784;
#   color: #000000;
# }
# #T_d5ebc_row1_col1 {
#   background-color: #00ea8a;
#   color: #000000;
# }
# #T_d5ebc_row2_col0, #T_d5ebc_row2_col1, #T_d5ebc_row2_col2, #T_d5ebc_row2_col3, #T_d5ebc_row2_col4, #T_d5ebc_row2_col5, #T_d5ebc_row2_col6 {
#   background-color: #00ff80;
#   color: #000000;
# }
# </style>
# <table id="T_d5ebc">
#   <thead>
#     <tr>
# ...

# %% [markdown]
# ---
#
#
#
# *   For Pclass= 1 and 2, survival of Female is almost 90-96% which is quiet high compared to the survival rate of Female in Pclass = 3 which is 50%.
# *   For Pclass = 1, survival of Male is higher (approx 36%) compared to other boarding classes for Male.
#
#
#
# ---

# %%
# Creating a Pclass list for labelling
Pclasses=["1st", "2nd", "3rd"]

# Instantiate a figure of size of 15 x 7 inches with 2 subplots
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,7))

# Creating a countplot of Pclass concerning Sex in the first subplot
sns.countplot(x='Pclass', data=df_clean, hue='Sex', palette='Dark2', ax=ax[0])

# Adding percentages to the bars
for p in ax[0].patches:
    percentage = '{:.2f}%'.format(100 * p.get_height() / total_datapoints)
    x = p.get_x() + p.get_width()/5
    y = p.get_y() + p.get_height()
    ax[0].annotate(percentage, (x, y))


# Adding some cosmetics - ticks, labels, title, legend and grid to the countplot.
ax[0].set_title(label='Pclass vs Sex', size=16)
ax[0].set_ylabel(ylabel='Number of Passengers', size=14)
ax[0].set_xlabel(xlabel='Class', size=14)
ax[0].set_xticklabels(labels=Pclasses, fontsize=12)
ax[0].set_yticklabels(labels=np.arange(0,400,50), fontsize=12)
ax[0].legend(labels=["Male", 'Female'])
ax[0].grid(visible=True)


# Creating a pointplot of embarked concerning survival in the second subplot
sns.pointplot(x='Pclass', y='Survived', hue='Sex', data=df_clean,
              palette='muted', ax=ax[1])

# Adding some cosmetics - ticks, labels, title, and grid to the pointplot.
ax[1].set_title(label='Pclass vs Sex', size=16)
ax[1].set_ylabel(ylabel="Passengers' Survival", size=14)
ax[1].set_xlabel(xlabel='Class', size=14)
ax[1].set_xticklabels(labels=Pclasses, fontsize=12)
ax[1].set_yticklabels(labels=np.round(a=np.arange(0.0, 1.2, 0.20), decimals=2),
                      fontsize=12)
ax[1].grid(visible=True)

# Setting a super title for the Age_band concerning survival plots
plt.suptitle(t='Influence of Sex and Pclass on Survival', size=16, y=1.0)

# Display the figures
plt.show()

# %% [markdown]
# ---
#
# - From both the graph, Men from Pclass=3 had a very low survival rate as compared to the rest of the classes.
#
# - From the right graph, It is evident that irrespective of Pclass, Women were given first priority while rescue.
#
# ---

# %% [markdown]
# <h3 style="font-family: 'Segoe UI', Roboto, Arial; font-size:28px; margin:0; background: -webkit-linear-gradient(90deg,#0f172a,#4f46e5); -webkit-background-clip: text; color: transparent;">5. Conclusion and Interpretation:</h3>
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Summarize key findings and insights derived from the analysis.</u></li>
# </ul>
# </p>

# %% [markdown]
# ---
# Women and children are most likely to survive.
# ---
#
#
# - On studying the previous questions, we observe that an **overwhelming** percentage of **women** & **children** have **survived** the titanic disaster.
#
# - But we should also take note that there were a **significant amount** of **men** present during the voyage.
#
# - **76%** of **females** **survived** whereas only **16%** of males **survived**.
#
# - Also the **survival** rate for a **male** is **very low** **irrespective** of the **class**.
#
# - Almost **all women in Pclass 1 and Pclass 2 survived** and nearly **all men in Pclass 2 and Pclass 3 died**.
#
# ---

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Reflect on the significance of different features in predicting survival.</u></li>
# </ul>
# </p>

# %% [markdown]
# ---
#
#
# - We have seen the **impact** of various factors such as **Gender**, **Age**, **Port of Embarkment**, **FamilySize** on the **rate of survival**.
#
# - **Women** have a **higher** chances of **survival** than men.
#
# - Passengers from **20-40 years** of age had a **very low survival** rate.
#
# - But since a lot of **Age** data was **missing**, we **can't conclude** how much impact Age really had on survival.
#
# - The **class** of the **passenger** seems to have played an **important** role in the rescue operation.
#
# - Passengers who were from the **1st class** were given **more priority** during the **rescue** than **rest** of the **passengers**.
#
# - Passengers who boarded from the **Cherbourg** port had a **higher survival** rate in contrast to the other two ports.
#
# - A lot of **3rd class passengers** from the **Southampton** port **died** in the accident.
#
# ---

# %% [markdown]
# <p style="margin:8px 0 0; color:#334155; font-size:16px;">
# <ul>
# <li><u>Suggest potential further steps or analyses that could be performed on the dataset.</u></li>
# </ul>
# </p>

# %% [markdown]
# ---
#
#
#
# *   As a potential further analysis we can take perform steps like doing more complex multivariate analysis of data, which can bring out some more insight of the dataset
# *   This dataset can be further analysed from the prospective of safety measures which can be taken to avoid disasters
# *   We can use this data to train a model which can predict the survivality of passengers
#
#
# ---
